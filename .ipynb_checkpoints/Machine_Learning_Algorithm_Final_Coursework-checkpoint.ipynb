# %% [markdown]
# # Abstract

# %% [markdown]
# This study is based on solar power prediction, where we will find the pattern between weather and ac power generation. In 1839, the ability of some materials to create an electrical charge from light was first observed by the French physicist Edmond Becquerel. Those were too inefficient for simple electric devices. Later on it was changed by hitting selenium. Based on this theory, in 1876, William Grylls Adams and Richard Evans Day published "The action of light on selenium 1876. Later on based on further development, instead of a single cell, we use multiple arrays of solar cells, which are used mostly in households and offices as a part of clean energy resources. This study focuses on the United Nations Sustainable Development Goal 7: Affordable and Clean Energy, addressing the global need for efficient and clean power sources. We know that there are a bunch of factors that affect the productivity of AC power for a solar panel which include irradiation, module temperature and ambient temperature. The global expansion of solar photovoltaics is central of achieving a sustainable energy transition, where governments are aiming to triple renewable energy capacity by 2030. Solar PV deployment is increasing in diverse climates beyond traditional mid-latitude regions, where environmental factors such as temperature, aerosols, and atmospheric conditions significantly influence energy output. Here, we will work on the Solar Power generation data from Kaggle to predict the impact of weather variables on solar power production, and we will optimize performance on our machine learning model. Key variables are solar irradiance variability, ambient temperature, and module temperature. As we will predict the power output so our model will be a regression model. By addressing environmental challenges, this research contributes to enhancing PV efficiency and advancement in global sustainable goals.

# %% [markdown]
# # Dataset Collection

# %% [markdown]
# This data has been gathered at two solar power plants in India over a 34-day period. Each dataset has 2 pair of files, one is the power generation and another is the sensor reading dataset. Later on in the study, we will merge these 2 datasets and use this to perform prediction for solar power generation prediction. For collecting the sensor data, the data was gathered at a plant level, which was placed optimally.
# This dataset is kaggle gold standard, which means it is a very high quality and also the data was taken from either in real world application or from lab environment, not from simulation, also it avoids garbage in and garbage out problem.

# %% [markdown]
# # Stakeholders and Audiences

# %% [markdown]
# This study finding will benefit mostly energy companies and also environmental organizations. The usage of machine learning algorithm has increased drastically in the power sectors. Like we will find so many examples that predicts wind power generation, grid based power production prediction.
# Also, these days a lot of companies are focusing on developing the goal of zero carbon emission like Apple , Microsoft, Toyota, Volkswagen. Developing a solar panel on the top of the factory is a modern approach. They can benefit from this study. This practice not only contributes to corporate environmental responsibility but also focuses global efforts to transition toward renewable energy and meet climate targets.
#
# Here are some factors that will benefit the Stakeholders :
#
# * Solar power forecasting will allow companies to plan energy storage and grid distribution, also it helps to reduce the waste and improve reliability
# * Cost-effective solution as it helps to reduce the usage of heavy machines to predict power output
# * If the prediction is reliable, it helps to support a decision on where to invest, based on the optimum temperature, sunlight we can create the solar plant in a perfect place for optimum output
# * Data-driven insights strengthen campaigns for clean energy adoption
# * Businesses can plan operations around predicted energy availability, reducing reliance on expensive non-renewable sources.

# %% [markdown]
# # Research Questions

# %% [markdown]
# The research question of my interest
# Data & environmental understanding
# * RQ1: Which environmental factors most strongly influence solar power generation?
# * RQ4: How does power generation vary across different timestamps?
#
# Modelling approach & dataset design
# * RQ3: Which regression model types are most suitable for this solar power dataset?
# * RQ6: What train–validation–test split strategy is most appropriate for this time‑series solar dataset?
# * RQ7: Which features can be removed without harming performance, and which features are most useful for prediction (feature importance/selection)?
#
# Model performance & robustness
# * RQ2: How accurately can the selected models predict solar power output on unseen data?
# * RQ5: Can the chosen models reliably capture and track short‑term fluctuations in power generation at different timestamps?
# * RQ9: Can the models accurately forecast solar power generation for the next few days to support grid management?
#
# Operational insights & stakeholder value
# * RQ8: How can predictive solar power generation models help stakeholders optimise energy planning and grid management?
# * RQ10: Can the model outputs be used to identify when solar panels require cleaning or maintenance?
# * RQ11: Can the models detect faulty or sub‑optimally performing equipment (e.g., underperforming inverters or strings)?

# %% [markdown]
# # Libraries

# %% [markdown]
# Before importing the libraries we need to make sure that those are already installed

# %%
# !pip install numpy pandas matplotlib seaborn scikit-learn
# Out:
# Requirement already satisfied: numpy in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: pandas in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (2.3.2)
# Requirement already satisfied: matplotlib in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (3.10.6)
# Requirement already satisfied: seaborn in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (1.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: scipy>=1.8.0 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install torch
# !pip install Optuna
# !pip install xgboost
# !pip install ipywidgets
# Out:
# Requirement already satisfied: torch in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (2.9.1)
# Requirement already satisfied: filelock in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from torch) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: Optuna in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (4.6.0)
# Requirement already satisfied: alembic>=1.5.0 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from Optuna) (1.17.2)
# Requirement already satisfied: colorlog in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from Optuna) (6.10.1)
# Requirement already satisfied: numpy in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from Optuna) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from Optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from Optuna) (2.0.44)
# Requirement already satisfied: tqdm in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from Optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from Optuna) (6.0.2)
# Requirement already satisfied: Mako in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from alembic>=1.5.0->Optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from alembic>=1.5.0->Optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from sqlalchemy>=1.4.2->Optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from Mako->alembic>=1.5.0->Optuna) (3.0.2)
# Requirement already satisfied: xgboost in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (3.1.2)
# Requirement already satisfied: numpy in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from xgboost) (2.3.3)
# Requirement already satisfied: nvidia-nccl-cu12 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from xgboost) (2.27.5)
# Requirement already satisfied: scipy in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from xgboost) (1.16.1)
# Requirement already satisfied: ipywidgets in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from ipywidgets) (9.1.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: decorator in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure_eval in /home/abrar/anaconda3/envs/pyprime/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import optuna
import xgboost as xgb
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.model_selection import GroupKFold
from xgboost import XGBRegressor
from xgboost import DMatrix
# For pytorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
# For widgets
import ipywidgets as widgets
from IPython.display import display
import warnings
warnings.filterwarnings("ignore")
# For Statistical analysis
from scipy import stats
from scipy.stats import f_oneway, ttest_rel
from scipy.stats import friedmanchisquare

# %% [markdown]
# # Util function

# %%
# Util
# In this section, we define reusable helper code for the project.
# Purpose of this function is to split train test based on unique dates
def split_and_scale_by_date(df, date_col="DATE", feature_cols=None, target_col="AC_POWER", split_ratio=0.8,random_state=42):
    """
    Here, we will split the data frame into training and testing sets by unique dates and apply MinMax scaling.

    Returns: X_train, X_test, y_train, y_test, train_df, test_df, X_scaler, y_scaler
    """
    if feature_cols is None:
        raise ValueError("feature_cols must be provided as a list of column names.")

    # 1. Unique dates
    unique_dates = df[date_col].drop_duplicates().values

    # 2. Shuffle dates (reproducible)
    rng = np.random.RandomState(random_state)
    rng.shuffle(unique_dates)

    # 3. Split dates into train/test
    split_index = int(len(unique_dates) * split_ratio)
    train_dates = unique_dates[:split_index]
    test_dates = unique_dates[split_index:]

    # 4. Select rows for each set
    train_df = df[df[date_col].isin(train_dates)].copy()
    test_df = df[df[date_col].isin(test_dates)].copy()

    # 5. Initialize scalers
    X_scaler = MinMaxScaler()
    y_scaler = MinMaxScaler()

    # 6. Fit on training data only
    X_train = X_scaler.fit_transform(train_df[feature_cols])
    y_train = y_scaler.fit_transform(train_df[[target_col]])

    # 7. Transform test data
    X_test = X_scaler.transform(test_df[feature_cols])
    y_test = y_scaler.transform(test_df[[target_col]])

    return X_train, X_test, y_train, y_test, train_df, test_df, X_scaler, y_scalery


def group_kfold_split_by_date(
    df,
    date_col="DATE",
    feature_cols=None,
    target_col="AC_POWER",
    n_splits=5
):
    """
    Performs Group K-Fold CV splitting based on unique dates.
    Returns a generator yielding:
        X_train, X_test, y_train, y_test,
        train_df, test_df, X_scaler, y_scaler
    """
    
    if feature_cols is None:
        raise ValueError("feature_cols must be provided as a list of column names.")
    
    # Group ID = each unique date
    df = df.copy()
    df["GROUP"] = df[date_col].astype(str)

    groups = df["GROUP"].values
    X_all = df[feature_cols].values
    y_all = df[target_col].values.reshape(-1, 1)

    gkf = GroupKFold(n_splits=n_splits)

    fold = 1
    for train_idx, test_idx in gkf.split(X_all, y_all, groups):

        # Raw data splits
        train_df = df.iloc[train_idx].copy()
        test_df  = df.iloc[test_idx].copy()

        # Extract arrays
        X_train_raw = X_all[train_idx]
        y_train_raw = y_all[train_idx]

        X_test_raw  = X_all[test_idx]
        y_test_raw  = y_all[test_idx]

        # Scaling on training only
        X_scaler = MinMaxScaler()
        y_scaler = MinMaxScaler()

        X_train = X_scaler.fit_transform(X_train_raw)
        y_train = y_scaler.fit_transform(y_train_raw)

        X_test = X_scaler.transform(X_test_raw)
        y_test = y_scaler.transform(y_test_raw)

        yield {
            "fold": fold,
            "X_train": X_train,
            "X_test": X_test,
            "y_train": y_train,
            "y_test": y_test,
            "train_df": train_df,
            "test_df": test_df,
            "X_scaler": X_scaler,
            "y_scaler": y_scaler
        }

        fold += 1

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Ethical Consideration

# %% [markdown]
# When considering this dataset for prediction of Solar Power generation there are several factors that was considered. First the provacy and consent concern are minimal one of the reason is this is technical data also it does not contain any personal information. However there may be a chance of biasness for specific geography region. This dataset was developed from India for specific time not across the whole year. So country and season wise the condition may vary. The risk of potential misuse must be acknowledged, predictions should be applied to improve energy planning rather than exploitive purposes.
# One thing to consider in here that the project focuses on one of the UN Sustainable Development Goal, which is the usage of renewable energy that reinforces the ethical foundation by promoting sustainability.

# %% [markdown]
# ## Data Loading Code

# %% [markdown]
# Here we have 2 csv file now for each plant data
# 1 : Plant Generation
# 2 : Plant Weather Sensor data

# %%
# Loading power generation data in df_power_generation and weather sensor data in df_weather_sensor
df_power_generation = pd.read_csv('Plant_Generation_Data.csv')
df_weather_sensor = pd.read_csv('Plant_Weather_Sensor_Data.csv')

# %%
# Now we will see the different data in here
# Loading power generation head
df_power_generation.head()
# Out:
#           DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1  15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2  15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3  15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4  15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
#
#    DAILY_YIELD  TOTAL_YIELD
# 0          0.0    6259559.0
# 1          0.0    6183645.0
# 2          0.0    6987759.0
# 3          0.0    7602960.0
# 4          0.0    7158964.0

# %%
# Loading weather sensor head
df_weather_sensor.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0  2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1  2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2  2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 3  2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 4  2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
#
#    MODULE_TEMPERATURE  IRRADIATION
# 0           22.857507          0.0
# 1           22.761668          0.0
# 2           22.592306          0.0
# 3           22.360852          0.0
# 4           22.165423          0.0

# %% [markdown]
# ## The Goal

# %% [markdown]
# As there are 2 different datasets at first we will analyze which data is necessary and which data is not required. We will also try to find missing values. If there are any missing values or duplicate values available we will clean the dataset. We may have to target merging the dataset and unify into one before processing into exploratory data analysis (EDA).

# %% [markdown]
# ## Dataset Cleaning and Preprocessing

# %%
# Here we will load power generation data from tail 
df_power_generation.tail()
# Out:
#               DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 68773  17-06-2020 23:45   4135001  uHbuxQJl8lW7ozc       0.0       0.0
# 68774  17-06-2020 23:45   4135001  wCURE6d3bPkepu2       0.0       0.0
# 68775  17-06-2020 23:45   4135001  z9Y9gH1T5YWrNuG       0.0       0.0
# 68776  17-06-2020 23:45   4135001  zBIq5rxdHJRwDNY       0.0       0.0
# 68777  17-06-2020 23:45   4135001  zVJPv84UY57bAof       0.0       0.0
#
#        DAILY_YIELD  TOTAL_YIELD
# 68773     5967.000    7287002.0
# 68774     5147.625    7028601.0
# 68775     5819.000    7251204.0
# 68776     5817.000    6583369.0
# 68777     5910.000    7363272.0

# %%
# Here we will load weather sensor data from tail 
df_weather_sensor.tail()
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 3177  2020-06-17 22:45:00   4135001  HmiyD2TTLFNqkNe            22.150570
# 3178  2020-06-17 23:00:00   4135001  HmiyD2TTLFNqkNe            22.129816
# 3179  2020-06-17 23:15:00   4135001  HmiyD2TTLFNqkNe            22.008275
# 3180  2020-06-17 23:30:00   4135001  HmiyD2TTLFNqkNe            21.969495
# 3181  2020-06-17 23:45:00   4135001  HmiyD2TTLFNqkNe            21.909288
#
#       MODULE_TEMPERATURE  IRRADIATION
# 3177           21.480377          0.0
# 3178           21.389024          0.0
# 3179           20.709211          0.0
# 3180           20.734963          0.0
# 3181           20.427972          0.0

# %% [markdown]
# From the power generation data frame we can say that multiple data was recorded for each time stamp. Now we will see how many datas are available in specific sample timestamp.

# %%
# Finding the unique number of values taken

df_power_generation['DATE_TIME'] = pd.to_datetime(
    df_power_generation['DATE_TIME'], format="%d-%m-%Y %H:%M"
)

# Filter date range
mask = (df_power_generation['DATE_TIME'] >= "2020-05-15") & \
       (df_power_generation['DATE_TIME'] <= "2020-06-17")

df_filtered = df_power_generation[mask]

# Group by DATE_TIME and count unique SOURCE_KEY
result = (
    df_filtered.groupby('DATE_TIME')['SOURCE_KEY']
    .nunique()
    .reset_index()
    .rename(columns={'SOURCE_KEY': 'unique_SOURCE_KEYs'})
)

result
# Out:
#                DATE_TIME  unique_SOURCE_KEYs
# 0    2020-05-15 00:00:00                  21
# 1    2020-05-15 00:15:00                  21
# 2    2020-05-15 00:30:00                  21
# 3    2020-05-15 00:45:00                  21
# 4    2020-05-15 01:00:00                  22
# ...                  ...                 ...
# 3060 2020-06-16 23:00:00                  22
# 3061 2020-06-16 23:15:00                  22
# 3062 2020-06-16 23:30:00                  22
# 3063 2020-06-16 23:45:00                  22
# 3064 2020-06-17 00:00:00                  22
#
# [3065 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# Ensure DATE_TIME is datetime
result['DATE_TIME'] = pd.to_datetime(result['DATE_TIME'])

plt.figure(figsize=(18,5))
plt.plot(result['DATE_TIME'], result['unique_SOURCE_KEYs'])

plt.xlabel("DATE_TIME")
plt.ylabel("Unique SOURCE_KEYs")
plt.title("Unique SOURCE_KEYs Over Time")

# Show only a few x-axis labels to avoid clutter
plt.xticks(result['DATE_TIME'][::200], rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# From the linechart we can see there is a variance of existence for unique timestamp numbers.
# Now we will try to find the missing values

# %%
# Convert timestamps to datetime 
df_weather_sensor['DATE_TIME'] = pd.to_datetime(df_weather_sensor['DATE_TIME'],dayfirst=True)
df_power_generation['DATE_TIME'] = pd.to_datetime(df_power_generation['DATE_TIME'],dayfirst=True)

# Find timestamps that exist in weather but not in generation
missing_data = df_weather_sensor[~df_weather_sensor['DATE_TIME'].isin(df_power_generation['DATE_TIME'])]
print(f"Missing timestamp : ", len(missing_data))
# Out:
# Missing timestamp :  25

# %%
missing_data
# Out:
#                DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 542  2020-05-20 23:00:00   4135001  HmiyD2TTLFNqkNe            23.830852
# 543  2020-05-20 23:15:00   4135001  HmiyD2TTLFNqkNe            23.701162
# 544  2020-05-20 23:30:00   4135001  HmiyD2TTLFNqkNe            23.589626
# 545  2020-05-20 23:45:00   4135001  HmiyD2TTLFNqkNe            23.569009
# 546  2020-05-21 00:00:00   4135001  HmiyD2TTLFNqkNe            23.497382
# 547  2020-05-21 00:15:00   4135001  HmiyD2TTLFNqkNe            23.228943
# 548  2020-05-21 00:30:00   4135001  HmiyD2TTLFNqkNe            23.204518
# 731  2020-05-23 05:15:00   4135001  HmiyD2TTLFNqkNe            21.900024
# 919  2020-05-25 05:45:00   4135001  HmiyD2TTLFNqkNe            22.930503
# 1274 2020-05-28 22:30:00   4135001  HmiyD2TTLFNqkNe            21.259225
# 1275 2020-05-28 22:45:00   4135001  HmiyD2TTLFNqkNe            21.242074
# 1276 2020-05-28 23:00:00   4135001  HmiyD2TTLFNqkNe            21.212694
# 1277 2020-05-28 23:15:00   4135001  HmiyD2TTLFNqkNe            21.195797
# 1278 2020-05-28 23:30:00   4135001  HmiyD2TTLFNqkNe            21.199087
# 1279 2020-05-28 23:45:00   4135001  HmiyD2TTLFNqkNe            21.157243
# 1280 2020-05-29 00:00:00   4135001  HmiyD2TTLFNqkNe            21.095442
# 1281 2020-05-29 00:15:00   4135001  HmiyD2TTLFNqkNe            21.076190
# 1282 2020-05-29 00:30:00   4135001  HmiyD2TTLFNqkNe            21.008919
# 1283 2020-05-29 00:45:00   4135001  HmiyD2TTLFNqkNe            20.794033
# 1284 2020-05-29 01:00:00   4135001  HmiyD2TTLFNqkNe            20.708745
# 1285 2020-05-29 01:15:00   4135001  HmiyD2TTLFNqkNe            20.666713
# 1286 2020-05-29 01:30:00   4135001  HmiyD2TTLFNqkNe            20.695156
# 1287 2020-05-29 01:45:00   4135001  HmiyD2TTLFNqkNe            20.707138
# 3111 2020-06-17 06:15:00   4135001  HmiyD2TTLFNqkNe            22.093398
# 3112 2020-06-17 06:30:00   4135001  HmiyD2TTLFNqkNe            22.275627
#
#       MODULE_TEMPERATURE  IRRADIATION
# 542            21.024118     0.000000
# 543            20.786399     0.000000
# 544            20.572882     0.000000
# 545            20.622103     0.000000
# 546            20.584137     0.000000
# 547            20.230347     0.000000
# 548            20.179942     0.000000
# 731            20.994995     0.000000
# 919            21.104395     0.001908
# 1274           20.277036     0.000000
# 1275           20.330682     0.000000
# 1276           20.339630     0.000000
# 1277           20.363869     0.000000
# 1278           20.352065     0.000000
# 1279           20.267047     0.000000
# 1280           20.236613     0.000000
# 1281           20.206651     0.000000
# 1282           20.190776     0.000000
# 1283           19.973201     0.000000
# 1284           19.866868     0.000000
# 1285           19.794505     0.000000
# 1286           19.810478     0.000000
# 1287           19.799289     0.000000
# 3111           20.822978     0.019175
# 3112           21.973568     0.034624

# %% [markdown]
# From the missing data we can see a pattern here irradiation is either 0 or so small nearby 0.

# %% [markdown]
# Now we will plot a graph to determine the Ac power generation distribution between day and night from the power generation dataframe

# %%
# Google colab help was taken in this part

import matplotlib.pyplot as plt
import pandas as pd

# Making sure DATE_TIME is datetime type
df_power_generation['DATE_TIME'] = pd.to_datetime(df_power_generation['DATE_TIME'], dayfirst=True)

# Extract hour from timestamp
df_power_generation['hour'] = df_power_generation['DATE_TIME'].dt.hour

# Compute average AC power per hour (or sum if you prefer)
hourly_ac_power = df_power_generation.groupby('hour')['AC_POWER'].mean()

# Defining night hours (6 PM to 6 AM)
night_hours = list(range(18, 24)) + list(range(0, 6))

# Plot
plt.figure(figsize=(12,6))
bars = plt.bar(hourly_ac_power.index, hourly_ac_power.values, color='skyblue')

# Highlight night hours in gray
for bar, hour in zip(bars, hourly_ac_power.index):
    if hour in night_hours:
        bar.set_color('gray')

plt.xlabel("Hour of Day")
plt.ylabel("Average AC Power (kW)")
plt.title("Average AC Power by Hour (Gray = Night)")
plt.xticks(range(0,24))
plt.show()

# %%
# Google colab help was taken to generate this graph

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Ensure datetime
df_weather_sensor['DATE_TIME'] = pd.to_datetime(df_weather_sensor['DATE_TIME'])
df_weather_sensor = df_weather_sensor.sort_values('DATE_TIME')

fig, ax = plt.subplots(figsize=(18,5))

# Plot irradiation line
ax.plot(df_weather_sensor['DATE_TIME'], df_weather_sensor['IRRADIATION'], color='orange')

# --- Shade night (6 PM → 6 AM next day) ---
for day in df_weather_sensor['DATE_TIME'].dt.date.unique():
    night_start = pd.Timestamp(f"{day} 18:00:00")
    night_end   = night_start + pd.Timedelta(hours=12)
    ax.axvspan(night_start, night_end, alpha=0.25, color='gray')

# --- X-axis: one tick per day at 12:00 PM ---
daily_ticks = pd.date_range(start=df_weather_sensor['DATE_TIME'].min().date(),
                            end=df_weather_sensor['DATE_TIME'].max().date(),
                            freq='D') + pd.Timedelta(hours=12)

ax.set_xticks(daily_ticks)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M'))

plt.xticks(rotation=45)
plt.xlabel("DATE_TIME")
plt.ylabel("IRRADIATION")
plt.title("Irradiation Over Time")

plt.tight_layout()
plt.show()

# %% [markdown]
# In the graph of irradiation vs time for weather sensor data the gray area is night time where the irradiation is 0 mostly.

# %%
# Now we will plot a bar chart from the missing value to show the distribution of timestamp in either day or night

import matplotlib.pyplot as plt

# Extract hour from DATE_TIME
missing_data['hour'] = missing_data['DATE_TIME'].dt.hour

# Count records per hour
hour_counts = missing_data['hour'].value_counts().sort_index()

# Define night hours (6 PM to 6 AM)
night_hours = list(range(18, 24)) + list(range(0, 6))

# Plot
plt.figure(figsize=(12,6))
bars = plt.bar(hour_counts.index, hour_counts.values, color='skyblue')

# Highlight night hours
for bar, hour in zip(bars, hour_counts.index):
    if hour in night_hours:
        bar.set_color('gray')

plt.xlabel("Hour of Day")
plt.ylabel("Number of Records")
plt.title("Distribution of Records by Hour (Gray = Night)")
plt.xticks(range(0,24))
plt.show()

# %%
# This bar chart will show the irradiation distribution 

import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.hist(missing_data['IRRADIATION'], bins=50, color='orange', edgecolor='black')
plt.xlabel("Irradiation")
plt.ylabel("Number of Records")
plt.title("Distribution of Solar Irradiation")
plt.show()

# %% [markdown]
# The weather dataset has a fixed 15-minute interval. From the graph of irradiation vs temperature, we can say that irradiation is 0 at night time. For the missing value bar chart of the distribution of records by hour, it is clear that the missing value most of the time is associated with nighttime. And from the distribution of solar irradiation, it is also clear that most of the irradiation is 0. After finding the missing timestamps, we can say that they occur at night, with zero irradiation and no active inverters. From the AC Power generation distribution bar chart, we can see that the power generation is 0 when there is no irradiation. So it is safe to assume that power production is 0 for the missing values.

# %% [markdown]
# ## Steps for Handling Missing Values

# %% [markdown]
# For handling the missing values, here are the steps we will take
#
# * We will group the generation data by timestamp and then sum the power from all inverters
# * The weather data list of timestamps will be used to reindex the grouped result
# * For a missing timestamp, the generated power will be filled with 0
#
#
# This will ensure that the dataset is consistent and is ready to be merged, and zero values are explicitly represented

# %%
#Group by timestamp and sum across inverters
power_generation_grouped = df_power_generation.groupby('DATE_TIME')[['DC_POWER', 'AC_POWER', 'DAILY_YIELD', 'TOTAL_YIELD']].sum()

# Reindex to match the weather timestamps exactly which keeps missing timestamps and fills them with 0
power_generation_grouped = power_generation_grouped.reindex(df_weather_sensor['DATE_TIME']).fillna(0)

#Index reset to make DATE_TIME a column 
power_generation_grouped = power_generation_grouped.reset_index().rename(columns={'index': 'DATE_TIME'})

# %%
power_generation_grouped
# Out:
#                DATE_TIME  DC_POWER  AC_POWER    DAILY_YIELD  TOTAL_YIELD
# 0    2020-05-15 00:00:00       0.0       0.0       0.000000  143581676.0
# 1    2020-05-15 00:15:00       0.0       0.0       0.000000  143581676.0
# 2    2020-05-15 00:30:00       0.0       0.0       0.000000  143581676.0
# 3    2020-05-15 00:45:00       0.0       0.0       0.000000  143581676.0
# 4    2020-05-15 01:00:00       0.0       0.0       0.000000  150761642.0
# ...                  ...       ...       ...            ...          ...
# 3177 2020-06-17 22:45:00       0.0       0.0  129571.000000  156142755.0
# 3178 2020-06-17 23:00:00       0.0       0.0  129571.000000  156142755.0
# 3179 2020-06-17 23:15:00       0.0       0.0  129571.000000  156142755.0
# 3180 2020-06-17 23:30:00       0.0       0.0  129571.000000  156142755.0
# 3181 2020-06-17 23:45:00       0.0       0.0  127962.767857  156142755.0
#
# [3182 rows x 5 columns]

# %% [markdown]
# Now we will try to understand the structure of the power generation and weather sensor

# %%
#This will describe the power generation dataframe
df_power_generation.describe()
# Out:
#                            DATE_TIME   PLANT_ID      DC_POWER      AC_POWER  \
# count                          68778    68778.0  68778.000000  68778.000000
# mean   2020-06-01 08:02:49.458256896  4135001.0   3147.426211    307.802752
# min              2020-05-15 00:00:00  4135001.0      0.000000      0.000000
# 25%              2020-05-24 00:45:00  4135001.0      0.000000      0.000000
# 50%              2020-06-01 14:30:00  4135001.0    429.000000     41.493750
# 75%              2020-06-09 20:00:00  4135001.0   6366.964286    623.618750
# max              2020-06-17 23:45:00  4135001.0  14471.125000   1410.950000
# std                              NaN        0.0   4036.457169    394.396439
#
#         DAILY_YIELD   TOTAL_YIELD          hour
# count  68778.000000  6.877800e+04  68778.000000
# mean    3295.968737  6.978712e+06     11.567216
# min        0.000000  6.183645e+06      0.000000
# 25%        0.000000  6.512003e+06      6.000000
# 50%     2658.714286  7.146685e+06     12.000000
# 75%     6274.000000  7.268706e+06     17.000000
# max     9163.000000  7.846821e+06     23.000000
# std     3145.178309  4.162720e+05      6.862477

# %% [markdown]
# We will set DATE_TIME as the index for both the weather and power-generation dataframes so that they become time-series datasets and can be accurately aligned, merged, and analyzed based on the same timestamps.

# %%
weather_df_set_index = df_weather_sensor.set_index('DATE_TIME')
generation_set_index = power_generation_grouped.set_index('DATE_TIME')

# %%
weather_df_set_index.describe()
# Out:
#         PLANT_ID  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# count     3182.0          3182.000000         3182.000000  3182.000000
# mean   4135001.0            25.531606           31.091015     0.228313
# std          0.0             3.354856           12.261222     0.300836
# min    4135001.0            20.398505           18.140415     0.000000
# 25%    4135001.0            22.705182           21.090553     0.000000
# 50%    4135001.0            24.613814           24.618060     0.024653
# 75%    4135001.0            27.920532           41.307840     0.449588
# max    4135001.0            35.252486           65.545714     1.221652

# %%
generation_set_index.describe()
# Out:
#             DC_POWER      AC_POWER    DAILY_YIELD   TOTAL_YIELD
# count    3182.000000   3182.000000    3182.000000  3.182000e+03
# mean    68021.364537   6652.152733   71234.359461  1.508344e+08
# std     87917.828216   8590.766175   66024.338720  1.694573e+07
# min         0.000000      0.000000       0.000000  0.000000e+00
# 25%         0.000000      0.000000      10.982143  1.520026e+08
# 50%      7512.333333    726.013988   66060.455358  1.535195e+08
# 75%    139358.133927  13649.681696  129056.477679  1.549854e+08
# max    298937.785710  29150.212499  193770.000000  1.561428e+08

# %%
# Checking length 
print (weather_df_set_index.info)
print (generation_set_index.info)
# Out:
# <bound method DataFrame.info of                      PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# DATE_TIME
# 2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
# ...                       ...              ...                  ...
# 2020-06-17 22:45:00   4135001  HmiyD2TTLFNqkNe            22.150570
# 2020-06-17 23:00:00   4135001  HmiyD2TTLFNqkNe            22.129816
# 2020-06-17 23:15:00   4135001  HmiyD2TTLFNqkNe            22.008275
# 2020-06-17 23:30:00   4135001  HmiyD2TTLFNqkNe            21.969495
# 2020-06-17 23:45:00   4135001  HmiyD2TTLFNqkNe            21.909288
#
#                      MODULE_TEMPERATURE  IRRADIATION
# DATE_TIME
# 2020-05-15 00:00:00           22.857507          0.0
# 2020-05-15 00:15:00           22.761668          0.0
# 2020-05-15 00:30:00           22.592306          0.0
# 2020-05-15 00:45:00           22.360852          0.0
# 2020-05-15 01:00:00           22.165423          0.0
# ...                                 ...          ...
# 2020-06-17 22:45:00           21.480377          0.0
# 2020-06-17 23:00:00           21.389024          0.0
# 2020-06-17 23:15:00           20.709211          0.0
# 2020-06-17 23:30:00           20.734963          0.0
# 2020-06-17 23:45:00           20.427972          0.0
#
# [3182 rows x 5 columns]>
# <bound method DataFrame.info of                      DC_POWER  AC_POWER    DAILY_YIELD  TOTAL_YIELD
# DATE_TIME
# 2020-05-15 00:00:00       0.0       0.0       0.000000  143581676.0
# 2020-05-15 00:15:00       0.0       0.0       0.000000  143581676.0
# 2020-05-15 00:30:00       0.0       0.0       0.000000  143581676.0
# 2020-05-15 00:45:00       0.0       0.0       0.000000  143581676.0
# 2020-05-15 01:00:00       0.0       0.0       0.000000  150761642.0
# ...                       ...       ...            ...          ...
# 2020-06-17 22:45:00       0.0       0.0  129571.000000  156142755.0
# 2020-06-17 23:00:00       0.0       0.0  129571.000000  156142755.0
# 2020-06-17 23:15:00       0.0       0.0  129571.000000  156142755.0
# 2020-06-17 23:30:00       0.0       0.0  129571.000000  156142755.0
# 2020-06-17 23:45:00       0.0       0.0  127962.767857  156142755.0
#
# [3182 rows x 4 columns]>

# %%
weather_df_set_index.index.equals(generation_set_index.index)
# Out:
# True

# %% [markdown]
# Now we will check if there is still any missing value

# %%
# Check for NaNs in weather data
print("Missing values in weather_df_set_index :")
print(weather_df_set_index.isna().sum())

# Check for NaNs in generation data
print("\nMissing values in generation_set_index:")
print(generation_set_index.isna().sum())
# Out:
# Missing values in weather_df_set_index :
# PLANT_ID               0
# SOURCE_KEY             0
# AMBIENT_TEMPERATURE    0
# MODULE_TEMPERATURE     0
# IRRADIATION            0
# dtype: int64
#
# Missing values in generation_set_index:
# DC_POWER       0
# AC_POWER       0
# DAILY_YIELD    0
# TOTAL_YIELD    0
# dtype: int64

# %% [markdown]
# There is no missing values for both of them also both of them has same length. So it is safe to merge data before EDA

# %% [markdown]
# # Merging Data And Feature Selection

# %% [markdown]
# Now our data cleaning and processing is done we can start for merging data. At first we will remove unnecessary columns

# %%
# Here we will show the feature importance and variation for weather_df_set_index 
# Calculate unique counts for each column (except the DATE_TIME index)
unique_counts = {
    "PLANT_ID": weather_df_set_index['PLANT_ID'].nunique(),
    "SOURCE_KEY": weather_df_set_index['SOURCE_KEY'].nunique(),
    "AMBIENT_TEMPERATURE": weather_df_set_index['AMBIENT_TEMPERATURE'].nunique(),
    "MODULE_TEMPERATURE": weather_df_set_index['MODULE_TEMPERATURE'].nunique(),
    "IRRADIATION": weather_df_set_index['IRRADIATION'].nunique()
}

# Convert to DataFrame
importance_df = pd.DataFrame.from_dict(unique_counts, orient='index', columns=['unique_values'])

# Normalize values (to look like feature importance)
importance_df['importance_score'] = importance_df['unique_values'] / importance_df['unique_values'].max()

# Plot
plt.figure(figsize=(10,6))
plt.bar(importance_df.index, importance_df['importance_score'])
plt.title("Feature Importance Based on Unique Value Variation\n(Low Variation = Not Useful Feature)")
plt.ylabel("Importance Score (Normalized)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# From this chart we can say plant id and source key is not necessary feature for our dataset. So we can remove these

# %%
# Plant id and source key are not required in this context as they are unnecessary features
weather_df_set_index = weather_df_set_index.drop(['PLANT_ID', 'SOURCE_KEY'], axis=1)
weather_df_set_index.head()
# Out:
#                      AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# DATE_TIME
# 2020-05-15 00:00:00            25.184316           22.857507          0.0
# 2020-05-15 00:15:00            25.084589           22.761668          0.0
# 2020-05-15 00:30:00            24.935753           22.592306          0.0
# 2020-05-15 00:45:00            24.846130           22.360852          0.0
# 2020-05-15 01:00:00            24.621525           22.165423          0.0

# %%
generation_set_index.describe()
# Out:
#             DC_POWER      AC_POWER    DAILY_YIELD   TOTAL_YIELD
# count    3182.000000   3182.000000    3182.000000  3.182000e+03
# mean    68021.364537   6652.152733   71234.359461  1.508344e+08
# std     87917.828216   8590.766175   66024.338720  1.694573e+07
# min         0.000000      0.000000       0.000000  0.000000e+00
# 25%         0.000000      0.000000      10.982143  1.520026e+08
# 50%      7512.333333    726.013988   66060.455358  1.535195e+08
# 75%    139358.133927  13649.681696  129056.477679  1.549854e+08
# max    298937.785710  29150.212499  193770.000000  1.561428e+08

# %%
# Here we will find relation between DC power generation and AC power generation
# Filtering out zero DC_POWER to focus on daytime generation
daytime_generation = generation_set_index[generation_set_index['DC_POWER'] > 0]

plt.figure(figsize=(10,6))
plt.scatter(daytime_generation['DC_POWER'], daytime_generation['AC_POWER'], alpha=0.5, color='orange')
plt.title("DC Power vs AC Power")
plt.xlabel("DC_POWER")
plt.ylabel("AC_POWER")
plt.grid(True)
plt.show()

# %% [markdown]
# From the statistical properties, we can remove TOTAL_YIELD  because it shows a cumulative counter, unlike AC_POWER, which fluctuates. TOTAL_YIELD only increases from a  minimum 0 to a maximum of 1.56 * 10^8) but never decreases. This behavior means it carries no time-specific information about power generation.
# Also, about DC_POWER we can remove it as we are predicting AC_POWER generation, and from this plot, it is clear that the relationship is linear, and there also DC_POWER is mostly a scaled value of AC_POWER, and it has no significant impact in this place

# %%
# Dropping dc power and total yield
generation_set_index = generation_set_index.drop(['DC_POWER', 'TOTAL_YIELD'], axis=1)
generation_set_index.head()
# Out:
#                      AC_POWER  DAILY_YIELD
# DATE_TIME
# 2020-05-15 00:00:00       0.0          0.0
# 2020-05-15 00:15:00       0.0          0.0
# 2020-05-15 00:30:00       0.0          0.0
# 2020-05-15 00:45:00       0.0          0.0
# 2020-05-15 01:00:00       0.0          0.0

# %% [markdown]
# Now based on timestamps of both dataset we can now safely merge

# %%
df = pd.merge(generation_set_index, weather_df_set_index, on='DATE_TIME')
df.head()
# Out:
#                      AC_POWER  DAILY_YIELD  AMBIENT_TEMPERATURE  \
# DATE_TIME
# 2020-05-15 00:00:00       0.0          0.0            25.184316
# 2020-05-15 00:15:00       0.0          0.0            25.084589
# 2020-05-15 00:30:00       0.0          0.0            24.935753
# 2020-05-15 00:45:00       0.0          0.0            24.846130
# 2020-05-15 01:00:00       0.0          0.0            24.621525
#
#                      MODULE_TEMPERATURE  IRRADIATION
# DATE_TIME
# 2020-05-15 00:00:00           22.857507          0.0
# 2020-05-15 00:15:00           22.761668          0.0
# 2020-05-15 00:30:00           22.592306          0.0
# 2020-05-15 00:45:00           22.360852          0.0
# 2020-05-15 01:00:00           22.165423          0.0

# %%
# Saving the merged data into a csv file
df.to_csv('merged_data.csv', index=False)

# %% [markdown]
# For the answer of RQ7 Which features can be removed without harming performance, and which features are most useful for prediction (feature importance/selection)?
# We can say from both datasets we can remove DC_POWER , TOTAL_YIELD , PLANT_ID, SOURCE_KEY without harming performance. The most useful feature is AMBIENT_TEMPERATURE, MODULE_TEMPERATURE and IRRADIATION

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## The Goal

# %% [markdown]
# Before we take a decision and define which model shall we use, we need to do some data analysis, we need to understand the relationship between the features. After that we can make a decision which model we will chose. Here we will try to find
# * How power generation varies over time
# * Weather impact on power generation
# * The correlations among the features

# %% [markdown]
# ## Approach

# %% [markdown]
# As we will predict power, at first we will find out the distributions of AC power, irradiation, module temperature and ambient temperature

# %%
# Distribution of AC power
plt.figure(figsize=(8, 6))
plt.hist(df['AC_POWER'], bins=30, edgecolor='black', color='skyblue')
plt.title('Distribution of AC Power')
plt.xlabel('AC Power')
plt.ylabel('Frequency')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# %%
# Distribution of irradiation
plt.figure(figsize=(8, 6))
plt.hist(df['IRRADIATION'], bins=30, edgecolor='black', color='orchid')
plt.title('Distribution of Irradiation')
plt.xlabel('Irradiation')
plt.ylabel('Frequency')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# %%
# Distribution of module temperature
plt.figure(figsize=(8, 6))
plt.hist(df['MODULE_TEMPERATURE'], bins=30, edgecolor='black', color='lightsalmon')
plt.title('Distribution of Module Temperature')
plt.xlabel('Module Temperature')
plt.ylabel('Frequency')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# %%
#Distribution of ambient temperature
plt.figure(figsize=(8, 6))
plt.hist(df['AMBIENT_TEMPERATURE'], bins=30, edgecolor='black', color='lightgreen')
plt.title('Distribution of Ambient Temperature')
plt.xlabel('Ambient Temperature')
plt.ylabel('Frequency')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# %% [markdown]
# From the distributions, we can say Ac power and Irradiation shows almost identical distributions. The module temperature displays a strong right skew. The ambient temperature distribution is more symmetric, centered in the low- to mid-20s °C, reflecting normal outdoor conditions in a warm climate with natural daily fluctuations. AC power and irradiation distributions are dominated by a sharp spike at or near zero, which proves the variance between day and night.

# %% [markdown]
# ## Feature Correlation heatmap

# %%
correlation_matrix = df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

# Add title
plt.title('Correlation Heatmap of Numerical Features')

# Display the plot
plt.show()

# %% [markdown]
# If we see this heatmap it is clear that DAILY_YIELD has very least relation with AC_POWER which comes as 0.1, so it is safe to ignore this feature in the development of our model. On the other hand ambient temperature has 0.73 , module temperature has 0.96 and irradiation has 1 which is a very strong relation. Now we will do scatter plot for each one vs AC power

# %%
# AC power vs ambient temperature
plt.figure(figsize=(10, 6))
plt.scatter(df['AMBIENT_TEMPERATURE'], df['AC_POWER'], alpha=0.7, color='green', label='Ambient Temperature vs. AC Power')
plt.title('AC Power vs. Ambient Temperature')
plt.xlabel('AMBIENT_TEMPERATURE')
plt.ylabel('AC_POWER')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# %%
# AC power vs module temperature

plt.figure(figsize=(10, 6))
plt.scatter(df['MODULE_TEMPERATURE'], df['AC_POWER'], alpha=0.7, color='red', label='Module Temperature vs. AC Power')
plt.title('AC Power vs. Module Temperature')
plt.xlabel('MODULE_TEMPERATURE')
plt.ylabel('AC_POWER')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# %%
# AC power vs irradiation

plt.figure(figsize=(10, 6))
plt.scatter(df['IRRADIATION'], df['AC_POWER'], alpha=0.7, color='purple', label='Irradiation vs. AC Power')
plt.title('AC Power vs. Irradiation')
plt.xlabel('IRRADIATION')
plt.ylabel('AC_POWER')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# %%
# Combined module temperature, irradiation , ambient temperature vs AC power

fig, ax = plt.subplots(figsize=(10, 6))

sns.scatterplot(data=df, x='AMBIENT_TEMPERATURE', y='AC_POWER', label='Ambient Temperature', ax=ax)
sns.scatterplot(data=df, x='MODULE_TEMPERATURE', y='AC_POWER', label='Module Temperature', ax=ax)
sns.scatterplot(data=df, x='IRRADIATION', y='AC_POWER', label='Irradiation', ax=ax)

ax.set_xlabel('Temperature/Irradiation')
ax.set_ylabel('AC Power')
ax.set_title('AC Power vs Temperature and Irradiation')
ax.legend()
plt.show()

# %% [markdown]
# Now we will check AC power variance over time, which will help us what type of model we will choose for our machine learning part.

# %%
plt.figure(figsize=(14, 4))
plt.plot(df.index, df['AC_POWER'])
plt.title('AC Power Over Time')
plt.xlabel('Date')
plt.ylabel('AC Power (kW)')
plt.grid(True)
plt.xticks(rotation=45)  
plt.tight_layout()
plt.show()

# %% [markdown]
# We will plot a graph to show the irradiation and AC power generation relation.

# %%
# Generative AI help was taken for this part
fig, ax1 = plt.subplots(figsize=(14, 4))

# Left axis for irradiation
ax1.plot(df.index, df['IRRADIATION'], color='tab:blue', label='Irradiation')
ax1.set_xlabel('Date')
ax1.set_ylabel('Irradiation', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Right axis for AC Power
ax2 = ax1.twinx()
ax2.plot(df.index, df['AC_POWER'], color='tab:orange', label='AC Power')
ax2.set_ylabel('AC Power (kW)', color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')

# Title and layout
plt.title('Irradiation and AC Power Over Time')
fig.tight_layout()
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Plotting based on different time
# Convert to datetime
# Ensure datetime conversion and extract date
# Select one day
sample_day = "2020-05-15"

# Filter one day using index
day_data = df.loc[sample_day]

fig, ax1 = plt.subplots(figsize=(12, 4))

# Irradiation (Blue)
ax1.plot(
    day_data.index, 
    day_data['IRRADIATION'], 
    color='blue', 
    label='Irradiation'
)
ax1.set_ylabel("Irradiation (kW/m²)", color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# AC Power (Red)
ax2 = ax1.twinx()
ax2.plot(
    day_data.index, 
    day_data['AC_POWER'], 
    color='red', 
    label='AC Power'
)
ax2.set_ylabel("AC Power (kW)", color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Title + legends
plt.title(f"Irradiation vs AC Power on {sample_day}")

# Add legends for both axes
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
plt.legend(lines_1 + lines_2, labels_1 + labels_2, loc="upper left")

plt.grid(True)
plt.show()

# %% [markdown]
# From the graphical analysis we are clear about some point.
#  * Here AC power generation is following time series where the rate fluctuates in different time
#  * Ambient temperature, module temperature and irradiation has strong correlation with AC power generation
#  * Irradiation has almost linear relation with AC power generation. As irradiation indicates sunlight so it is obvious power generation   will be affected in a proportion
#  * The relation between ambient and module temperature is not following any linear relation hence it has a proportional relation with AC power generation

# %% [markdown]
# # Model Selection

# %% [markdown]
# From the scatter plot it is clear that it is time series data also the relation is not linear. As we have to consider 3 features for non linear relations, these are the models suits better
# * Random Forest Regressor
# * Xgboost Regressor
# * HistGradientBoosting Regressor
# * Feed-forward Neural Network
#
# For our work in here, we will use 3 models (Random Forest, Xgboost, and Feed-forward neural network) and compare their performance. Also as a part of innovation, we will develop a neural network and evaluate its performance.

# %% [markdown]
# ### Random Forest

# %% [markdown]
# <!-Need to paraphrase->
#
# A random forest is a meta estimator that fits a number of decision tree regressors on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting. During training, the tree builder makes decisions about where to direct samples with missing values relative to split points based on gain. It works by creating multiple decision trees, each trained on a random subset of the data. The process begins with Bootstrap sampling, where random rows of data are selected with replacement to form different training datasets for each tree. After this, we do feature sampling where only a random subset of features is used to build each tree, ensuring diversity in the models.

# %% [markdown]
# ### Xgboost

# %% [markdown]
# <!-Need to paraphrase->
#
# Traditional machine learning models like decision trees and random forests are easy to interpret but often struggle with accuracy on complex datasets. XGBoost short form for eXtreme Gradient Boosting is an advanced machine learning algorithm designed for efficiency, speed and high performance. It builds decision trees sequentially with each tree attempting to correct the mistakes made by the previous one. The process can be broken down as follows:
#
# * Start with a base learner: The first model decision tree is trained on the data. In regression tasks this base model simply predicts the average of the target variable.
# * Calculate the errors: After training the first tree the errors between the predicted and actual values are calculated.
# * Train the next tree: The next tree is trained on the errors of the previous tree. This step attempts to correct the errors made by the first tree.
# * Repeat the process: This process continues with each new tree trying to correct the errors of the previous trees until a stopping criterion is met.
# * Combine the predictions: The final prediction is the sum of the predictions from all the trees.

# %% [markdown]
# ### Feedforward Neural Network

# %% [markdown]
# <!-Need to paraphrase->
#
# Feedforward Neural Networks have a structured layered design where data flows sequentially through each layer.
#
# * Input Layer: The input layer consists of neurons that receive the input data. Each neuron in the input layer represents a feature of the input data.
# * Hidden Layers: One or more hidden layers are placed between the input and output layers. These layers are responsible for learning the complex patterns in the data. Each neuron in a hidden layer applies a weighted sum of inputs followed by a non-linear activation function.
# * Output Layer: The output layer provides the final output of the network. The number of neurons in this layer corresponds to the number of classes in a classification problem or the number of outputs in a regression problem.

# %% [markdown]
# ### Hyperparameter Finetuning

# %% [markdown]
# Hyper parameter tuning is a concept where in order to get high score from a model and good prediction capability from a model we will tune or change the values of the hyper parameters. Like for example when we are calling a model from sklearn library there are a bunch of parameters that we need to pass before training the model. The parameters that we will use we can either use grid search cv, manual search or using optuna.
# For our condition we will use optuna in all of our model hyper parameter tuning.

# %% [markdown]
# ### Why Optuna is better ?

# %% [markdown]
# | Method          | Pros                                                                 | Cons                                                           | Trials Needed |
# |-----------------|----------------------------------------------------------------------|----------------------------------------------------------------|---------------|
# | Grid Search     |  Exhaustive search guarantees finding the best combination in the grid<br> Easy to implement |  Very slow for large parameter spaces<br> Does not scale well<br> Can be wasteful on unimportant parameters | High          |
# | Random Search   |  Faster than Grid Search<br> Can explore a wider parameter space<br> Easy to implement |  May miss the global optimum<br> Results can vary due to randomness | Medium        |
# | Optuna    |  Efficient Bayesian optimization<br> Adaptive search focuses on promising regions<br> Fewer trials needed for good results |  Slightly more complex setup<br> May require tuning of TPE parameters | Low           |

# %% [markdown]
# ### Dataset Test Train Split

# %% [markdown]
# For our dataset we can't split test and train dataset randomly or shuffle randomly. We have to split based on time. Otherwise it will not give a good output based on different timestamp.
# From the prebuilt function that we have made earlier and put in util function we will do train test split based on date and time. As the data is time series so we can't randomly shuffle and split. We have to split based on our timeline.
# What we have to do is based on unique timestamps we will shuffle the datasets. The code is mentioned below.

# %%
# Reset Index
df = df.reset_index()

# Convert the date_time column to datetime format
df['DATE_TIME'] = pd.to_datetime(df['DATE_TIME'])

# Add a date column
df['DATE'] = df['DATE_TIME'].dt.date

df.head()
# Out:
#             DATE_TIME  AC_POWER  DAILY_YIELD  AMBIENT_TEMPERATURE  \
# 0 2020-05-15 00:00:00       0.0          0.0            25.184316
# 1 2020-05-15 00:15:00       0.0          0.0            25.084589
# 2 2020-05-15 00:30:00       0.0          0.0            24.935753
# 3 2020-05-15 00:45:00       0.0          0.0            24.846130
# 4 2020-05-15 01:00:00       0.0          0.0            24.621525
#
#    MODULE_TEMPERATURE  IRRADIATION        DATE
# 0           22.857507          0.0  2020-05-15
# 1           22.761668          0.0  2020-05-15
# 2           22.592306          0.0  2020-05-15
# 3           22.360852          0.0  2020-05-15
# 4           22.165423          0.0  2020-05-15

# %%
# Getting the unique dates based on duplicate
unique_dates = df['DATE'].drop_duplicates().values
# 1. Shuffle the dates
np.random.seed(42)
np.random.shuffle(unique_dates)

# 2. Split the dates into train/test sets
split_ratio = 0.8
split_index = int(len(unique_dates) * split_ratio)
train_dates = unique_dates[:split_index]
test_dates  = unique_dates[split_index:]

# 3. Use those dates to select rows from df
train_df = df[df['DATE'].isin(train_dates)]
test_df  = df[df['DATE'].isin(test_dates)]

# Select features and target

features = ['AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION']
target = 'AC_POWER'

# Initialize scalers
X_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()

# Fit only on training data
X_train = X_scaler.fit_transform(train_df[features])
y_train = y_scaler.fit_transform(train_df[[target]])

# Transform the test data
X_test = X_scaler.transform(test_df[features])
y_test = y_scaler.transform(test_df[[target]])

# %% [markdown]
# Now using this split theory and GroupKFold library we will create a function that will do the dataset split. Instead of using random seed we will use group k fold

# %%
# Convert date to group
df['GROUP'] = df['DATE'].astype(str)

# Prepare features and target
X = df[features].values
y = df['AC_POWER'].values.reshape(-1,1)
groups = df['GROUP']

# Initialize Group K-Fold
gkf = GroupKFold(n_splits=5)

# Loop through folds
for fold, (train_idx, test_idx) in enumerate(gkf.split(X, y, groups), start=1):
    X_train_raw, X_test_raw = X[train_idx], X[test_idx]
    y_train_raw, y_test_raw = y[train_idx], y[test_idx]

    # Scale features and target
    X_scaler, y_scaler = MinMaxScaler(), MinMaxScaler()
    X_train = X_scaler.fit_transform(X_train_raw)
    X_test  = X_scaler.transform(X_test_raw)
    y_train = y_scaler.fit_transform(y_train_raw)
    y_test  = y_scaler.transform(y_test_raw)

    # Return fold info (dictionary)
    fold_data = {
        "fold": fold,
        "X_train": X_train, "X_test": X_test,
        "y_train": y_train, "y_test": y_test,
        "X_scaler": X_scaler, "y_scaler": y_scaler
    }

# %% [markdown]
# For our future usage we will make it like a function and putting the function group_kfold_split_by_date under Util for future usage

# %% [markdown]
# ### We will start with random forest at first

# %% [markdown]
# Now we will try to fine the best hyper parameters by finetuning using optuna beysian method

# %% [markdown]
# ### Finding Best Dataset using GroupKFold Split For Random Forest

# %% [markdown]
# Before hyper parameter tuning we will do Group K-Fold to shuffle dataset and find the best dataset that brings highest score

# %%
# Not necessary will review and remove later
results = []

for fold_data in group_kfold_split_by_date(
        df,
        date_col="DATE",
        feature_cols=features,
        target_col="AC_POWER",
        n_splits=5
):

    fold = fold_data["fold"]
    X_train = fold_data["X_train"]
    X_test  = fold_data["X_test"]
    y_train = fold_data["y_train"]
    y_test  = fold_data["y_test"]
    y_scaler = fold_data["y_scaler"]

    # Model with Optuna-tuned parameters
    model = RandomForestRegressor(**best_params)
    model.fit(X_train, y_train.ravel())

    preds = model.predict(X_test)
    preds = y_scaler.inverse_transform(preds.reshape(-1,1))
    real_y_test = y_scaler.inverse_transform(y_test)

    r2 = r2_score(real_y_test, preds)
    mae = mean_absolute_error(real_y_test, preds)
    rmse = np.sqrt(mean_squared_error(real_y_test, preds))

    results.append({
        "fold": fold,
        "r2": r2,
        "mae": mae,
        "rmse": rmse
    })

results_df = pd.DataFrame(results)
print(results_df)
# Out:
#    fold        r2         mae        rmse
# 0     1  0.988706  349.359842  841.099606
# 1     2  0.992937  314.941989  694.911011
# 2     3  0.995320  293.252941  588.240900
# 3     4  0.996535  278.224768  529.575442
# 4     5  0.996405  272.162377  537.951385

# %%
# Finding the fold with the highest R²
best_fold_idx = results_df['r2'].idxmax()
best_fold_number = results_df.loc[best_fold_idx, 'fold']

print(f"Best Fold: {best_fold_number}")
print(f"R²: {results_df.loc[best_fold_idx, 'r2']}")
print(f"MAE: {results_df.loc[best_fold_idx, 'mae']}")
print(f"RMSE: {results_df.loc[best_fold_idx, 'rmse']}")

# Retrieve the train/test data for the best fold
best_fold_data = list(group_kfold_split_by_date(
    df,
    date_col="DATE",
    feature_cols=features,
    target_col="AC_POWER",
    n_splits=5
))[best_fold_number]

X_train = best_fold_data["X_train"]
X_test  = best_fold_data["X_test"]
y_train = best_fold_data["y_train"]
y_test  = best_fold_data["y_test"]
train_df = best_fold_data["train_df"]
test_df  = best_fold_data["test_df"]
y_scaler = best_fold_data["y_scaler"]

print("Train/Test datasets for best fold retrieved.")
# Out:
# Best Fold: 4
# R²: 0.9964664499020895
# MAE: 281.9462058899566
# RMSE: 534.8241270021279
# Train/Test datasets for best fold retrieved.

# %% [markdown]
# #### Hyper Parameter Tuning

# %% [markdown]
# For different dataset we used GroupKfold shuffle to create, train and test the model. From the test we have found the best R square which we will consider as the best dataset. Now using this dataset we will do optuna beysian hyper parameter tuning

# %%
# Obsolute function will remove after some explanation 
def objective(trial):

    # Hyperparameter search space
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 1200),
        "max_depth": trial.suggest_int("max_depth", 5, 60),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_float("max_features", 0.3, 1.0),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
        "random_state": 30,
        "n_jobs": -1
    }

    # Build model
    model = RandomForestRegressor(**params)
    model.fit(X_train, y_train)

    # Predict
    preds = model.predict(X_test)

    # Metrics
    r2  = r2_score(y_test, preds)
    mae = mean_absolute_error(y_test, preds)
    mse = mean_squared_error(y_test, preds)
    rmse = np.sqrt(mse)

    # You can print metrics for each trial (optional)
    trial.set_user_attr("MAE", mae)
    trial.set_user_attr("MSE", mse)
    trial.set_user_attr("RMSE", rmse)

    return r2 


# Create study Bayesian optimization
study_rf = optuna.create_study(
    direction="maximize",
    sampler=optuna.samplers.TPESampler()
)

# Run optimization
study_rf.optimize(objective, n_trials=50, show_progress_bar=True)

# Best trial
best_trial = study_rf.best_trial

print("Best Trial Results")
print("Best R² Score:", best_trial.value)

print("\nBest Hyperparameters:")
for k, v in best_trial.params.items():
    print(f"  {k}: {v}")

print("\nOther Metrics for Best Trial:")
print("MAE :", best_trial.user_attrs["MAE"])
print("MSE :", best_trial.user_attrs["MSE"])
print("RMSE:", best_trial.user_attrs["RMSE"])
# Out:
# [I 2025-11-30 09:13:10,290] A new study created in memory with name: no-name-3336c4f1-aa21-4d1a-a724-0f5616a6f38d
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-11-30 09:13:11,531] Trial 0 finished with value: 0.9954404686774365 and parameters: {'n_estimators': 998, 'max_depth': 28, 'min_samples_split': 14, 'min_samples_leaf': 5, 'max_features': 0.8713730017955681, 'bootstrap': True}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:12,250] Trial 1 finished with value: 0.9949389765402596 and parameters: {'n_estimators': 795, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': 0.9936749708117472, 'bootstrap': False}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:13,491] Trial 2 finished with value: 0.9934822935521161 and parameters: {'n_estimators': 1077, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 0.6612828051264938, 'bootstrap': True}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:14,608] Trial 3 finished with value: 0.992721390979049 and parameters: {'n_estimators': 971, 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 0.6454386579121391, 'bootstrap': True}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:15,395] Trial 4 finished with value: 0.9951377044256691 and parameters: {'n_estimators': 786, 'max_depth': 56, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 0.7524355008272425, 'bootstrap': False}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:15,857] Trial 5 finished with value: 0.9916293174416372 and parameters: {'n_estimators': 381, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 0.4285386820563948, 'bootstrap': True}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:16,531] Trial 6 finished with value: 0.9943244185635394 and parameters: {'n_estimators': 361, 'max_depth': 58, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.4198624036921368, 'bootstrap': True}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:17,070] Trial 7 finished with value: 0.9935105583697716 and parameters: {'n_estimators': 423, 'max_depth': 15, 'min_samples_split': 13, 'min_samples_leaf': 5, 'max_features': 0.6622585297637533, 'bootstrap': True}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:17,623] Trial 8 finished with value: 0.9934709131279695 and parameters: {'n_estimators': 453, 'max_depth': 54, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 0.654329710030839, 'bootstrap': True}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:18,018] Trial 9 finished with value: 0.9952243956527442 and parameters: {'n_estimators': 312, 'max_depth': 33, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 0.7089086076563521, 'bootstrap': True}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:19,153] Trial 10 finished with value: 0.9951405535734631 and parameters: {'n_estimators': 1189, 'max_depth': 35, 'min_samples_split': 19, 'min_samples_leaf': 8, 'max_features': 0.976914101797246, 'bootstrap': False}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:19,444] Trial 11 finished with value: 0.9953665162076699 and parameters: {'n_estimators': 218, 'max_depth': 32, 'min_samples_split': 14, 'min_samples_leaf': 2, 'max_features': 0.8383486937884801, 'bootstrap': True}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:20,204] Trial 12 finished with value: 0.9953440450857097 and parameters: {'n_estimators': 542, 'max_depth': 25, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 0.8397407852204932, 'bootstrap': True}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:21,078] Trial 13 finished with value: 0.9953779973846949 and parameters: {'n_estimators': 623, 'max_depth': 44, 'min_samples_split': 17, 'min_samples_leaf': 2, 'max_features': 0.8616243193207456, 'bootstrap': True}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:21,774] Trial 14 finished with value: 0.9949408836952044 and parameters: {'n_estimators': 624, 'max_depth': 46, 'min_samples_split': 19, 'min_samples_leaf': 4, 'max_features': 0.8815267193713792, 'bootstrap': False}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:23,083] Trial 15 finished with value: 0.9930467700206954 and parameters: {'n_estimators': 925, 'max_depth': 44, 'min_samples_split': 17, 'min_samples_leaf': 7, 'max_features': 0.5370790346439459, 'bootstrap': True}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:24,080] Trial 16 finished with value: 0.9953255339040131 and parameters: {'n_estimators': 720, 'max_depth': 43, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.9041477486060225, 'bootstrap': True}. Best is trial 0 with value: 0.9954404686774365.
# [I 2025-11-30 09:13:25,172] Trial 17 finished with value: 0.9955463333705786 and parameters: {'n_estimators': 919, 'max_depth': 22, 'min_samples_split': 16, 'min_samples_leaf': 10, 'max_features': 0.7797707907000291, 'bootstrap': True}. Best is trial 17 with value: 0.9955463333705786.
# [I 2025-11-30 09:13:26,115] Trial 18 finished with value: 0.9952678333332456 and parameters: {'n_estimators': 940, 'max_depth': 23, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 0.7713829150793118, 'bootstrap': False}. Best is trial 17 with value: 0.9955463333705786.
# [I 2025-11-30 09:13:27,436] Trial 19 finished with value: 0.9930309009983168 and parameters: {'n_estimators': 1104, 'max_depth': 23, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 0.5403968134689618, 'bootstrap': True}. Best is trial 17 with value: 0.9955463333705786.
# [I 2025-11-30 09:13:28,521] Trial 20 finished with value: 0.9929203137692657 and parameters: {'n_estimators': 869, 'max_depth': 17, 'min_samples_split': 13, 'min_samples_leaf': 9, 'max_features': 0.331321314965624, 'bootstrap': True}. Best is trial 17 with value: 0.9955463333705786.
# [I 2025-11-30 09:13:29,330] Trial 21 finished with value: 0.9954586456514901 and parameters: {'n_estimators': 596, 'max_depth': 26, 'min_samples_split': 16, 'min_samples_leaf': 5, 'max_features': 0.9183927020457989, 'bootstrap': True}. Best is trial 17 with value: 0.9955463333705786.
# [I 2025-11-30 09:13:31,108] Trial 22 finished with value: 0.9954731285234953 and parameters: {'n_estimators': 1026, 'max_depth': 26, 'min_samples_split': 16, 'min_samples_leaf': 5, 'max_features': 0.9286566200100571, 'bootstrap': True}. Best is trial 17 with value: 0.9955463333705786.
# [I 2025-11-30 09:13:32,927] Trial 23 finished with value: 0.995501853137892 and parameters: {'n_estimators': 1068, 'max_depth': 19, 'min_samples_split': 17, 'min_samples_leaf': 7, 'max_features': 0.9397751726063339, 'bootstrap': True}. Best is trial 17 with value: 0.9955463333705786.
# [I 2025-11-30 09:13:34,976] Trial 24 finished with value: 0.9955053561500552 and parameters: {'n_estimators': 1060, 'max_depth': 19, 'min_samples_split': 18, 'min_samples_leaf': 7, 'max_features': 0.9333508387236832, 'bootstrap': True}. Best is trial 17 with value: 0.9955463333705786.
# [I 2025-11-30 09:13:37,105] Trial 25 finished with value: 0.9954983765347545 and parameters: {'n_estimators': 1184, 'max_depth': 19, 'min_samples_split': 20, 'min_samples_leaf': 7, 'max_features': 0.7798344381221726, 'bootstrap': True}. Best is trial 17 with value: 0.9955463333705786.
# [I 2025-11-30 09:13:38,571] Trial 26 finished with value: 0.995215687966667 and parameters: {'n_estimators': 1110, 'max_depth': 11, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 0.9603141836445069, 'bootstrap': False}. Best is trial 17 with value: 0.9955463333705786.
# [I 2025-11-30 09:13:39,934] Trial 27 finished with value: 0.9955054687122318 and parameters: {'n_estimators': 902, 'max_depth': 20, 'min_samples_split': 18, 'min_samples_leaf': 7, 'max_features': 0.8105327115660066, 'bootstrap': True}. Best is trial 17 with value: 0.9955463333705786.
# [I 2025-11-30 09:13:41,222] Trial 28 finished with value: 0.9955499494122564 and parameters: {'n_estimators': 873, 'max_depth': 11, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 0.8026569054448595, 'bootstrap': True}. Best is trial 28 with value: 0.9955499494122564.
# [I 2025-11-30 09:13:42,479] Trial 29 finished with value: 0.9955584340817262 and parameters: {'n_estimators': 850, 'max_depth': 9, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 0.7321632273043163, 'bootstrap': True}. Best is trial 29 with value: 0.9955584340817262.
# [I 2025-11-30 09:13:43,872] Trial 30 finished with value: 0.9955583130880221 and parameters: {'n_estimators': 843, 'max_depth': 9, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 0.7204430336567638, 'bootstrap': True}. Best is trial 29 with value: 0.9955584340817262.
# [I 2025-11-30 09:13:45,127] Trial 31 finished with value: 0.9955593699725036 and parameters: {'n_estimators': 839, 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 0.7292985264615677, 'bootstrap': True}. Best is trial 31 with value: 0.9955593699725036.
# [I 2025-11-30 09:13:46,483] Trial 32 finished with value: 0.9955574979387263 and parameters: {'n_estimators': 823, 'max_depth': 9, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 0.7031055709368641, 'bootstrap': True}. Best is trial 31 with value: 0.9955593699725036.
# [I 2025-11-30 09:13:47,616] Trial 33 finished with value: 0.9951172848783859 and parameters: {'n_estimators': 795, 'max_depth': 5, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 0.7147914790721253, 'bootstrap': True}. Best is trial 31 with value: 0.9955593699725036.
# [I 2025-11-30 09:13:48,653] Trial 34 finished with value: 0.9926380575780935 and parameters: {'n_estimators': 741, 'max_depth': 8, 'min_samples_split': 19, 'min_samples_leaf': 8, 'max_features': 0.5948246369888873, 'bootstrap': True}. Best is trial 31 with value: 0.9955593699725036.
# [I 2025-11-30 09:13:49,888] Trial 35 finished with value: 0.9952688055875653 and parameters: {'n_estimators': 855, 'max_depth': 11, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 0.713702085665125, 'bootstrap': False}. Best is trial 31 with value: 0.9955593699725036.
# [I 2025-11-30 09:13:51,198] Trial 36 finished with value: 0.9924850481171552 and parameters: {'n_estimators': 788, 'max_depth': 8, 'min_samples_split': 19, 'min_samples_leaf': 9, 'max_features': 0.61087203713653, 'bootstrap': True}. Best is trial 31 with value: 0.9955593699725036.
# [I 2025-11-30 09:13:52,300] Trial 37 finished with value: 0.995528261833477 and parameters: {'n_estimators': 677, 'max_depth': 16, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': 0.7283210572374353, 'bootstrap': True}. Best is trial 31 with value: 0.9955593699725036.
# [I 2025-11-30 09:13:54,128] Trial 38 finished with value: 0.9955495742236817 and parameters: {'n_estimators': 996, 'max_depth': 13, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_features': 0.6814313826719995, 'bootstrap': True}. Best is trial 31 with value: 0.9955593699725036.
# [I 2025-11-30 09:13:55,083] Trial 39 finished with value: 0.9922936200033062 and parameters: {'n_estimators': 814, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_features': 0.6114261803753589, 'bootstrap': False}. Best is trial 31 with value: 0.9955593699725036.
# [I 2025-11-30 09:13:56,282] Trial 40 finished with value: 0.9954957059421022 and parameters: {'n_estimators': 694, 'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 0.7480521165191792, 'bootstrap': True}. Best is trial 31 with value: 0.9955593699725036.
# [I 2025-11-30 09:13:57,803] Trial 41 finished with value: 0.9955609772028339 and parameters: {'n_estimators': 850, 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 0.8158870985399901, 'bootstrap': True}. Best is trial 41 with value: 0.9955609772028339.
# [I 2025-11-30 09:13:59,184] Trial 42 finished with value: 0.9955320362050627 and parameters: {'n_estimators': 829, 'max_depth': 10, 'min_samples_split': 19, 'min_samples_leaf': 8, 'max_features': 0.6806198953464201, 'bootstrap': True}. Best is trial 41 with value: 0.9955609772028339.
# [I 2025-11-30 09:14:00,491] Trial 43 finished with value: 0.9951316774171817 and parameters: {'n_estimators': 748, 'max_depth': 5, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 0.7445643607301692, 'bootstrap': True}. Best is trial 41 with value: 0.9955609772028339.
# [I 2025-11-30 09:14:02,010] Trial 44 finished with value: 0.9927770827874887 and parameters: {'n_estimators': 980, 'max_depth': 9, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 0.6387430491102225, 'bootstrap': True}. Best is trial 41 with value: 0.9955609772028339.
# [I 2025-11-30 09:14:03,742] Trial 45 finished with value: 0.9955293868198634 and parameters: {'n_estimators': 838, 'max_depth': 13, 'min_samples_split': 19, 'min_samples_leaf': 8, 'max_features': 0.8215991942956622, 'bootstrap': True}. Best is trial 41 with value: 0.9955609772028339.
# [I 2025-11-30 09:14:05,016] Trial 46 finished with value: 0.9955414148270227 and parameters: {'n_estimators': 744, 'max_depth': 15, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': 0.6909099941306609, 'bootstrap': True}. Best is trial 41 with value: 0.9955609772028339.
# [I 2025-11-30 09:14:06,058] Trial 47 finished with value: 0.9885412017088604 and parameters: {'n_estimators': 657, 'max_depth': 5, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 0.5628372904500172, 'bootstrap': True}. Best is trial 41 with value: 0.9955609772028339.
# [I 2025-11-30 09:14:07,990] Trial 48 finished with value: 0.9955563533125794 and parameters: {'n_estimators': 965, 'max_depth': 12, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_features': 0.8679358098347336, 'bootstrap': True}. Best is trial 41 with value: 0.9955609772028339.
# [I 2025-11-30 09:14:08,919] Trial 49 finished with value: 0.9931992343864414 and parameters: {'n_estimators': 771, 'max_depth': 37, 'min_samples_split': 19, 'min_samples_leaf': 6, 'max_features': 0.4674101091362425, 'bootstrap': False}. Best is trial 41 with value: 0.9955609772028339.
# Best Trial Results
# Best R² Score: 0.9955609772028339
#
# Best Hyperparameters:
#   n_estimators: 850
#   max_depth: 10
#   min_samples_split: 20
#   min_samples_leaf: 9
#   max_features: 0.8158870985399901
#   bootstrap: True
#
# Other Metrics for Best Trial:
# MAE : 0.009942083462736671
# MSE : 0.00042592274066605824
# RMSE: 0.020637895742203424

# %% [markdown]
# In this part we will do a bunch of things. For hyper parameter tuning we will pass the required parameters, and find the best combination using optuna beysian hyper parameter tuning method. Also for the group k fold split we will split the dataset and will iterate in a loop. After that we will save the results in a csv file for future usage. Based on highest R square we will save the train test dataset.

# %% [markdown]
# ## Main Code for Random Forest

# %%
# Global variables to track the best dataset across all trials
best_overall_r2 = -np.inf
best_overall_train_df = None
best_overall_test_df = None

def objective(trial, metrics_csv="fold_metrics_random_forest.csv", dataset_csv="best_dataset_random_forest.csv"):
    global best_overall_r2, best_overall_train_df, best_overall_test_df

    # 1. Hyperparameter search space
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 1200),
        "max_depth": trial.suggest_int("max_depth", 5, 60),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_float("max_features", 0.3, 1.0),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
        "random_state": 42,
        "n_jobs": -1
    }

    fold_metrics = []

    # 2. Group K-Fold CV
    for fold_data in group_kfold_split_by_date(
        df,
        date_col="DATE",
        feature_cols=features,
        target_col="AC_POWER",
        n_splits=5
    ):
        X_train = fold_data["X_train"]
        X_test  = fold_data["X_test"]
        y_train = fold_data["y_train"].ravel()
        y_test  = fold_data["y_test"].ravel()
        y_scaler = fold_data["y_scaler"]

        # 3. Build and fit model
        model = RandomForestRegressor(**params)
        model.fit(X_train, y_train)

        # 4. Predict and inverse transform
        preds = model.predict(X_test).reshape(-1, 1)
        preds = y_scaler.inverse_transform(preds)
        real_y = y_scaler.inverse_transform(y_test.reshape(-1, 1))

        # 5. Metrics
        r2 = r2_score(real_y, preds)
        mae = mean_absolute_error(real_y, preds)
        rmse = np.sqrt(mean_squared_error(real_y, preds))

        fold_metrics.append({
            "fold": fold_data["fold"],
            "r2": r2,
            "mae": mae,
            "rmse": rmse
        })

        # Track the best fold across all trials
        if r2 > best_overall_r2:
            best_overall_r2 = r2
            best_overall_train_df = fold_data["train_df"]
            best_overall_test_df  = fold_data["test_df"]

    # 6. Save fold metrics for this trial
    fold_metrics_df = pd.DataFrame(fold_metrics)
    fold_metrics_df["trial_number"] = trial.number
    fold_metrics_df.to_csv(metrics_csv, mode='a', index=False,
                           header=not pd.io.common.file_exists(metrics_csv))

    # 7. Store mean metrics in trial attributes
    mean_r2 = np.mean([m["r2"] for m in fold_metrics])
    trial.set_user_attr("mean_mae", np.mean([m["mae"] for m in fold_metrics]))
    trial.set_user_attr("mean_rmse", np.mean([m["rmse"] for m in fold_metrics]))

    return mean_r2

# %%
# Create study → Bayesian optimization
study_rf = optuna.create_study(
    direction="maximize",
    sampler=optuna.samplers.TPESampler()
)

# Run optimization
study_rf.optimize(objective, n_trials=50, show_progress_bar=True)

# Best trial
best_trial = study_rf.best_trial

print("Best Trial Results")
print("Mean R² Score across folds:", best_trial.value)
print("Mean MAE across folds :", best_trial.user_attrs["mean_mae"])
print("Mean RMSE across folds:", best_trial.user_attrs["mean_rmse"])

print("\nBest Hyperparameters:")
for k, v in best_trial.params.items():
    print(f"  {k}: {v}")

# Save the global best dataset after all trials
if best_overall_train_df is not None and best_overall_test_df is not None:
    best_overall_train_df.to_csv("best_train_dataset_random_forest.csv", index=False)
    best_overall_test_df.to_csv("best_test_dataset_random_forest.csv", index=False)
    print("Best train/test datasets saved with highest R² score:", best_overall_r2)


print("\nBest train/test datasets with highest R² across all trials saved to CSV.")
best_train_path = "best_train_dataset_random_forest.csv"
best_test_path  = "best_test_dataset_random_forest.csv"
print("Train dataset:", best_train_path)
print("Test dataset :", best_test_path)

# Optional: load it to check shape
best_train_df = pd.read_csv(best_train_path)
best_test_df  = pd.read_csv(best_test_path)
print("Train shape:", best_train_df.shape)
print("Test shape :", best_test_df.shape)
# Out:
# [I 2025-11-30 10:52:37,966] A new study created in memory with name: no-name-5eeba38f-1d99-463d-8732-7e5a63a98ee7
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-11-30 10:52:41,234] Trial 0 finished with value: 0.9920065403401475 and parameters: {'n_estimators': 678, 'max_depth': 57, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 0.3615137755785428, 'bootstrap': False}. Best is trial 0 with value: 0.9920065403401475.
# [I 2025-11-30 10:52:44,244] Trial 1 finished with value: 0.9938036976387906 and parameters: {'n_estimators': 579, 'max_depth': 45, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 0.7815259957250869, 'bootstrap': False}. Best is trial 1 with value: 0.9938036976387906.
# [I 2025-11-30 10:52:46,621] Trial 2 finished with value: 0.9916119701403151 and parameters: {'n_estimators': 397, 'max_depth': 57, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 0.316256452929749, 'bootstrap': True}. Best is trial 1 with value: 0.9938036976387906.
# [I 2025-11-30 10:52:52,339] Trial 3 finished with value: 0.9938022102655445 and parameters: {'n_estimators': 1083, 'max_depth': 36, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': 0.7265967559480297, 'bootstrap': False}. Best is trial 1 with value: 0.9938036976387906.
# [I 2025-11-30 10:52:56,595] Trial 4 finished with value: 0.9909228942532087 and parameters: {'n_estimators': 800, 'max_depth': 37, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 0.6286245598865425, 'bootstrap': False}. Best is trial 1 with value: 0.9938036976387906.
# [I 2025-11-30 10:52:58,475] Trial 5 finished with value: 0.9898812924158854 and parameters: {'n_estimators': 344, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 0.4972918386769002, 'bootstrap': False}. Best is trial 1 with value: 0.9938036976387906.
# [I 2025-11-30 10:53:04,176] Trial 6 finished with value: 0.9913047771904807 and parameters: {'n_estimators': 902, 'max_depth': 38, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_features': 0.5115380671750219, 'bootstrap': False}. Best is trial 1 with value: 0.9938036976387906.
# [I 2025-11-30 10:53:12,131] Trial 7 finished with value: 0.9938605269288351 and parameters: {'n_estimators': 1061, 'max_depth': 50, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': 0.7575351995211255, 'bootstrap': False}. Best is trial 7 with value: 0.9938605269288351.
# [I 2025-11-30 10:53:18,627] Trial 8 finished with value: 0.9938009851969415 and parameters: {'n_estimators': 849, 'max_depth': 51, 'min_samples_split': 14, 'min_samples_leaf': 5, 'max_features': 0.8619281032019341, 'bootstrap': False}. Best is trial 7 with value: 0.9938605269288351.
# [I 2025-11-30 10:53:21,573] Trial 9 finished with value: 0.9919002347847036 and parameters: {'n_estimators': 463, 'max_depth': 55, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 0.6630345829382592, 'bootstrap': False}. Best is trial 7 with value: 0.9938605269288351.
# [I 2025-11-30 10:53:30,704] Trial 10 finished with value: 0.99390887405584 and parameters: {'n_estimators': 1183, 'max_depth': 20, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': 0.8937240148045555, 'bootstrap': True}. Best is trial 10 with value: 0.99390887405584.
# [I 2025-11-30 10:53:40,837] Trial 11 finished with value: 0.993923123664737 and parameters: {'n_estimators': 1145, 'max_depth': 19, 'min_samples_split': 19, 'min_samples_leaf': 6, 'max_features': 0.9876186970795315, 'bootstrap': True}. Best is trial 11 with value: 0.993923123664737.
# [I 2025-11-30 10:53:49,886] Trial 12 finished with value: 0.9939225345671912 and parameters: {'n_estimators': 1145, 'max_depth': 20, 'min_samples_split': 20, 'min_samples_leaf': 5, 'max_features': 0.9929789322746856, 'bootstrap': True}. Best is trial 11 with value: 0.993923123664737.
# [I 2025-11-30 10:53:58,281] Trial 13 finished with value: 0.9939223493982986 and parameters: {'n_estimators': 986, 'max_depth': 22, 'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': 0.971130554149125, 'bootstrap': True}. Best is trial 11 with value: 0.993923123664737.
# [I 2025-11-30 10:54:08,793] Trial 14 finished with value: 0.9939509983228436 and parameters: {'n_estimators': 1136, 'max_depth': 22, 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_features': 0.9632250019361217, 'bootstrap': True}. Best is trial 14 with value: 0.9939509983228436.
# [I 2025-11-30 10:54:18,051] Trial 15 finished with value: 0.9938509273390483 and parameters: {'n_estimators': 975, 'max_depth': 9, 'min_samples_split': 17, 'min_samples_leaf': 1, 'max_features': 0.8872695479771052, 'bootstrap': True}. Best is trial 14 with value: 0.9939509983228436.
# [I 2025-11-30 10:54:20,266] Trial 16 finished with value: 0.9938896771450565 and parameters: {'n_estimators': 209, 'max_depth': 27, 'min_samples_split': 17, 'min_samples_leaf': 6, 'max_features': 0.935552614168837, 'bootstrap': True}. Best is trial 14 with value: 0.9939509983228436.
# [I 2025-11-30 10:54:31,000] Trial 17 finished with value: 0.9939579086660674 and parameters: {'n_estimators': 1197, 'max_depth': 12, 'min_samples_split': 17, 'min_samples_leaf': 3, 'max_features': 0.8255944653195778, 'bootstrap': True}. Best is trial 17 with value: 0.9939579086660674.
# [I 2025-11-30 10:54:37,828] Trial 18 finished with value: 0.9939711544748417 and parameters: {'n_estimators': 732, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.8226788953180925, 'bootstrap': True}. Best is trial 18 with value: 0.9939711544748417.
# [I 2025-11-30 10:54:45,809] Trial 19 finished with value: 0.9939497236382833 and parameters: {'n_estimators': 698, 'max_depth': 14, 'min_samples_split': 11, 'min_samples_leaf': 2, 'max_features': 0.8205715665921626, 'bootstrap': True}. Best is trial 18 with value: 0.9939711544748417.
# [I 2025-11-30 10:54:51,972] Trial 20 finished with value: 0.9939609521731064 and parameters: {'n_estimators': 563, 'max_depth': 13, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': 0.6692026395166837, 'bootstrap': True}. Best is trial 18 with value: 0.9939711544748417.
# [I 2025-11-30 10:54:58,728] Trial 21 finished with value: 0.9939626554582089 and parameters: {'n_estimators': 603, 'max_depth': 13, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': 0.6822029376884758, 'bootstrap': True}. Best is trial 18 with value: 0.9939711544748417.
# [I 2025-11-30 10:55:04,428] Trial 22 finished with value: 0.9914194306027095 and parameters: {'n_estimators': 575, 'max_depth': 29, 'min_samples_split': 11, 'min_samples_leaf': 2, 'max_features': 0.6263588780227801, 'bootstrap': True}. Best is trial 18 with value: 0.9939711544748417.
# [I 2025-11-30 10:55:09,751] Trial 23 finished with value: 0.993361556770307 and parameters: {'n_estimators': 565, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 0.6812705116176946, 'bootstrap': True}. Best is trial 18 with value: 0.9939711544748417.
# [I 2025-11-30 10:55:16,018] Trial 24 finished with value: 0.9914230145672687 and parameters: {'n_estimators': 782, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 2, 'max_features': 0.5671106028302386, 'bootstrap': True}. Best is trial 18 with value: 0.9939711544748417.
# [I 2025-11-30 10:55:21,143] Trial 25 finished with value: 0.9939820041342052 and parameters: {'n_estimators': 640, 'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 0.7133052768382592, 'bootstrap': True}. Best is trial 25 with value: 0.9939820041342052.
# [I 2025-11-30 10:55:26,273] Trial 26 finished with value: 0.9939908668404138 and parameters: {'n_estimators': 637, 'max_depth': 27, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 0.7286863451454237, 'bootstrap': True}. Best is trial 26 with value: 0.9939908668404138.
# [I 2025-11-30 10:55:32,105] Trial 27 finished with value: 0.9940013375082911 and parameters: {'n_estimators': 743, 'max_depth': 27, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 0.7396079117662695, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:55:35,997] Trial 28 finished with value: 0.9939822949446349 and parameters: {'n_estimators': 493, 'max_depth': 28, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 0.7609754069166373, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:55:39,526] Trial 29 finished with value: 0.991404641518297 and parameters: {'n_estimators': 483, 'max_depth': 30, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 0.5571346250275379, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:55:41,600] Trial 30 finished with value: 0.9910940469913649 and parameters: {'n_estimators': 288, 'max_depth': 25, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': 0.44515292531107403, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:55:47,111] Trial 31 finished with value: 0.99399087327972 and parameters: {'n_estimators': 669, 'max_depth': 33, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.7296201827706692, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:55:51,083] Trial 32 finished with value: 0.9939836535366586 and parameters: {'n_estimators': 502, 'max_depth': 33, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 0.7749231381305196, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:55:56,513] Trial 33 finished with value: 0.9939905099835601 and parameters: {'n_estimators': 667, 'max_depth': 33, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 0.778550363987857, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:56:01,782] Trial 34 finished with value: 0.9939597496900451 and parameters: {'n_estimators': 666, 'max_depth': 43, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 0.7184859762468803, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:56:07,553] Trial 35 finished with value: 0.9939739363240493 and parameters: {'n_estimators': 737, 'max_depth': 42, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 0.7979301224272057, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:56:13,608] Trial 36 finished with value: 0.9919682985036259 and parameters: {'n_estimators': 842, 'max_depth': 33, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 0.6032938166101197, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:56:19,435] Trial 37 finished with value: 0.9939909043826614 and parameters: {'n_estimators': 628, 'max_depth': 39, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 0.7241115740637193, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:56:25,952] Trial 38 finished with value: 0.993840180823754 and parameters: {'n_estimators': 785, 'max_depth': 38, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': 0.7212952902360902, 'bootstrap': False}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:56:31,583] Trial 39 finished with value: 0.9939465394033219 and parameters: {'n_estimators': 626, 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': 0.7438359524883702, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:56:34,445] Trial 40 finished with value: 0.9910001392372466 and parameters: {'n_estimators': 433, 'max_depth': 47, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 0.5999577646388087, 'bootstrap': False}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:56:40,802] Trial 41 finished with value: 0.9939905099835601 and parameters: {'n_estimators': 667, 'max_depth': 35, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 0.7918407026991793, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:56:47,358] Trial 42 finished with value: 0.9939664326199343 and parameters: {'n_estimators': 721, 'max_depth': 31, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': 0.8601619323692377, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:56:52,434] Trial 43 finished with value: 0.9939908807764072 and parameters: {'n_estimators': 542, 'max_depth': 26, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 0.6968026688676962, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:56:57,450] Trial 44 finished with value: 0.9939495915823228 and parameters: {'n_estimators': 542, 'max_depth': 25, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': 0.6976631286906034, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:57:00,317] Trial 45 finished with value: 0.9919055094532098 and parameters: {'n_estimators': 393, 'max_depth': 25, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 0.6398089925276761, 'bootstrap': False}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:57:08,783] Trial 46 finished with value: 0.9940006569917437 and parameters: {'n_estimators': 894, 'max_depth': 36, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.7503965377657634, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:57:17,323] Trial 47 finished with value: 0.9908849909363495 and parameters: {'n_estimators': 918, 'max_depth': 37, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': 0.6521233540203669, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:57:24,890] Trial 48 finished with value: 0.9911346190827972 and parameters: {'n_estimators': 834, 'max_depth': 47, 'min_samples_split': 9, 'min_samples_leaf': 5, 'max_features': 0.3070527282053997, 'bootstrap': True}. Best is trial 27 with value: 0.9940013375082911.
# [I 2025-11-30 10:57:33,211] Trial 49 finished with value: 0.9935685670986742 and parameters: {'n_estimators': 891, 'max_depth': 35, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 0.7435537787358292, 'bootstrap': False}. Best is trial 27 with value: 0.9940013375082911.
# Best Trial Results
# Mean R² Score across folds: 0.9940013375082911
# Mean MAE across folds : 300.7581924961212
# Mean RMSE across folds: 637.349102459566
#
# Best Hyperparameters:
#   n_estimators: 743
#   max_depth: 27
#   min_samples_split: 6
#   min_samples_leaf: 4
#   max_features: 0.7396079117662695
#   bootstrap: True
# Best train/test datasets saved with highest R² score: 0.9965409140667852
#
# Best train/test datasets with highest R² across all trials saved to CSV.
# Train dataset: best_train_dataset_random_forest.csv
# Test dataset : best_test_dataset_random_forest.csv
# Train shape: (2530, 8)
# Test shape : (652, 8)

# %%
# Get best hyperparameters from Optuna
best_params = best_trial.params
best_params["random_state"] = 30
best_params["n_jobs"] = -1

# Retrieve the best fold datasets for the trial
best_train_df = pd.read_csv('best_train_dataset_random_forest.csv')
best_test_df  = pd.read_csv('best_test_dataset_random_forest.csv')

# Separate features and target
X_train = best_train_df[features].values
y_train = best_train_df["AC_POWER"].values.ravel()

X_test  = best_test_df[features].values
y_test  = best_test_df["AC_POWER"].values.ravel()

# Fit the final Random Forest model
best_rf_model = RandomForestRegressor(**best_params)
best_rf_model.fit(X_train, y_train)

# Predict on test set
final_pred = best_rf_model.predict(X_test)

# Evaluate
final_r2 = r2_score(y_test, final_pred)
final_mae = mean_absolute_error(y_test, final_pred)
final_rmse = np.sqrt(mean_squared_error(y_test, final_pred))

print("Final R²:", final_r2)
print("Final MAE:", final_mae)
print("Final RMSE:", final_rmse)
# Out:
# Final R²: 0.9965359269567856
# Final MAE: 278.22608086593345
# Final RMSE: 529.5401387572753

# %% [markdown]
# ### Graphical Analysis

# %%
y_pred_rf = final_pred

# %%
plt.figure(figsize=(5,5))
plt.scatter(y_test, y_pred_rf, s=10, alpha=0.4)
lo, hi = min(np.min(y_test), np.min(y_pred_rf)), max(np.max(y_test), np.max(y_pred_rf))
plt.plot([lo, hi], [lo, hi], 'r--', lw=2, label='Ideal y=x')
plt.xlabel('Actual (y_test)'); plt.ylabel('Predicted (y_pred)')
plt.title('Predicted vs Actual for random forest model '); plt.legend(); plt.tight_layout();
plt.show()

# %%
# Ensuring y_test and y_pred are both 1D arrays of same length
y_test_aligned = np.array(y_test).flatten()
y_pred_aligned = np.array(y_pred_rf).flatten()

# Compute residuals
residuals = y_test_aligned - y_pred_aligned

# Residual plot
plt.figure(figsize=(6,5))
plt.scatter(y_pred_aligned, residuals, alpha=0.5, s=15, color='purple')
plt.axhline(0, color='red', linestyle='--', lw=2)  # horizontal line at 0
plt.xlabel('Predicted Values')
plt.ylabel('Residuals (y_test - y_pred)')
plt.title('Residual Plot for RandomForest Model')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.plot(y_test, label='True')
plt.plot(y_pred_rf, label='Predicted')
plt.legend()
plt.title('Model Predictions vs True AC POWER Kw')
plt.xlabel('Time Step')
plt.ylabel('AC_POWER (kW)')
plt.show()

# %% [markdown]
# ### Statistical Analysis For Random Forest

# %%
# 1. Load fold metrics CSV

metrics_csv = "fold_metrics_random_forest.csv"  # Change if needed
metrics_df = pd.read_csv(metrics_csv)

# %%
# Describe 
desc_stats = metrics_df[['r2','mae','rmse']].describe()
desc_stats
# Out:
#                r2         mae        rmse
# count  250.000000  250.000000  250.000000
# mean     0.993135  331.063001  682.294947
# std      0.003319   50.781149  129.980603
# min      0.984062  272.195225  529.158821
# 25%      0.990201  287.088438  549.604727
# 50%      0.994001  317.157166  679.766339
# 75%      0.996252  356.450315  818.507882
# max      0.996541  490.102302  999.168558

# %%
# Fold-level performance analysis
fold_stats = metrics_df.groupby('fold')[['r2','mae','rmse']].agg(['mean','std','min','max'])
fold_stats
# Out:
#             r2                                       mae             \
#           mean       std       min       max        mean        std
# fold
# 1     0.987710  0.001539  0.984062  0.988810  379.568080  44.405372
# 2     0.991849  0.001617  0.987609  0.992980  344.052849  42.216539
# 3     0.994683  0.000911  0.992224  0.995378  316.626145  33.996443
# 4     0.995644  0.001274  0.992397  0.996541  315.453968  52.880389
# 5     0.995789  0.000876  0.993113  0.996434  299.613964  36.803700
#
#                                     rmse
#              min         max        mean        std         min         max
# fold
# 1     346.022321  490.102302  875.802996  53.395777  837.218476  999.168558
# 2     313.810683  460.143995  743.207125  71.023138  692.770434  920.403126
# 3     292.120773  404.551320  624.920848  51.651076  584.619806  758.263128
# 4     277.488381  446.158300  588.200413  82.093520  529.158821  784.511604
# 5     272.195225  403.678945  579.343353  57.853664  535.764406  744.524975

# %%
# Visualize
sns.set(style="whitegrid")

# Boxplots
plt.figure(figsize=(12,5))
plt.subplot(1,3,1)
sns.boxplot(x='fold', y='r2', data=metrics_df)
plt.title('R² per Fold')

plt.subplot(1,3,2)
sns.boxplot(x='fold', y='mae', data=metrics_df)
plt.title('MAE per Fold')

plt.subplot(1,3,3)
sns.boxplot(x='fold', y='rmse', data=metrics_df)
plt.title('RMSE per Fold')

plt.tight_layout()
plt.show()

# %%
# Line plots: metric trend across trials
plt.figure(figsize=(12,4))
sns.lineplot(x='trial_number', y='r2', hue='fold', data=metrics_df, marker='o')
plt.title("R² across Trials per Fold")
plt.xlabel("Trial Number")
plt.ylabel("R²")
plt.show()

# %%
# Example: ANOVA to check if R² differs significantly between folds
fold_r2_groups = [metrics_df[metrics_df['fold']==f]['r2'] for f in metrics_df['fold'].unique()]
anova_result = f_oneway(*fold_r2_groups)
print("\nANOVA for R² across folds")
print(f"F-statistic: {anova_result.statistic:.4f}, p-value: {anova_result.pvalue:.4f}")

# Paired t-test example: fold 1 vs fold 2 R²
t_stat, p_val = ttest_rel(metrics_df[metrics_df['fold']==1]['r2'].values,
                          metrics_df[metrics_df['fold']==2]['r2'].values)
print("\nPaired t-test Fold 1 vs Fold 2 R²:")
print(f"t-statistic: {t_stat:.4f}, p-value: {p_val:.4f}")
# Out:
# ANOVA for R² across folds
# F-statistic: 1.3407, p-value: 0.2554
#
# Paired t-test Fold 1 vs Fold 2 R²:
# t-statistic: -7.6313, p-value: 0.0000

# %%
# 7. Confidence intervals
def compute_ci(data, confidence=0.95):
    mean = np.mean(data)
    sem  = stats.sem(data)
    ci_lower, ci_upper = stats.t.interval(confidence, len(data)-1, loc=mean, scale=sem)
    return mean, ci_lower, ci_upper

print("\n95% Confidence Intervals ")
for metric in ['r2','mae','rmse']:
    mean, ci_lower, ci_upper = compute_ci(metrics_df[metric])
    print(f"{metric}: Mean={mean:.4f}, 95% CI=({ci_lower:.4f}, {ci_upper:.4f})")
# Out:
# 95% Confidence Intervals
# r2: Mean=0.9931, 95% CI=(0.9927, 0.9935)
# mae: Mean=331.0630, 95% CI=(324.7375, 337.3885)
# rmse: Mean=682.2949, 95% CI=(666.1040, 698.4859)

# %%
best_row = metrics_df.loc[metrics_df['r2'].idxmax()]
print("\n Best Trial/Fold")
print(best_row)
print(f"Trial {best_row['trial_number']} - Fold {best_row['fold']} has the highest R²: {best_row['r2']:.4f}")
# Out:
#  Best Trial/Fold
# fold              4.000000
# r2                0.996541
# mae             278.462386
# rmse            529.158821
# trial_number     34.000000
# Name: 173, dtype: float64
# Trial 34.0 - Fold 4.0 has the highest R²: 0.9965

# %% [markdown]
# ## XGBoost

# %%
results_xgb = []

for fold_data in group_kfold_split_by_date(
        df,
        date_col="DATE",
        feature_cols=features,
        target_col="AC_POWER",
        n_splits=5
):

    fold = fold_data["fold"]
    X_train = fold_data["X_train"]
    X_test  = fold_data["X_test"]
    y_train = fold_data["y_train"]
    y_test  = fold_data["y_test"]
    y_scaler = fold_data["y_scaler"]

    # XGBoost model
    xgb_model = XGBRegressor(
        n_estimators=best_params.get("n_estimators", 500),
        max_depth=best_params.get("max_depth", 6),
        learning_rate=best_params.get("learning_rate", 0.1),
        subsample=best_params.get("subsample", 1.0),
        colsample_bytree=best_params.get("max_features", 1.0),
        random_state=30,
        n_jobs=-1
    )

    # Fit model
    xgb_model.fit(X_train, y_train.ravel())

    # Predict and inverse scale
    preds = xgb_model.predict(X_test)
    preds = y_scaler.inverse_transform(preds.reshape(-1,1))
    real_y_test = y_scaler.inverse_transform(y_test)

    # Metrics
    r2 = r2_score(real_y_test, preds)
    mae = mean_absolute_error(real_y_test, preds)
    rmse = np.sqrt(mean_squared_error(real_y_test, preds))

    results_xgb.append({
        "fold": fold,
        "r2": r2,
        "mae": mae,
        "rmse": rmse
    })

results_xgb_df = pd.DataFrame(results_xgb)
print(results_xgb_df)
# Out:
#    fold        r2         mae        rmse
# 0     1  0.985986  406.162588  936.922474
# 1     2  0.990856  373.108026  790.670834
# 2     3  0.994183  336.505810  655.835262
# 3     4  0.993196  385.620727  742.163628
# 4     5  0.994240  346.410334  680.876032

# %%
# Finding the fold with the highest R² for XGBoost
best_fold_idx = results_xgb_df['r2'].idxmax()
best_fold_number = results_xgb_df.loc[best_fold_idx, 'fold']

print(f"Best Fold (XGBoost): {best_fold_number}")
print(f"R²: {results_xgb_df.loc[best_fold_idx, 'r2']}")
print(f"MAE: {results_xgb_df.loc[best_fold_idx, 'mae']}")
print(f"RMSE: {results_xgb_df.loc[best_fold_idx, 'rmse']}")

best_fold_idx_list = best_fold_number - 1 

# Retrieve the train/test data for the best fold
best_fold_data = list(group_kfold_split_by_date(
    df,
    date_col="DATE",
    feature_cols=features,
    target_col="AC_POWER",
    n_splits=5
))[best_fold_idx_list]

X_train = best_fold_data["X_train"]
X_test  = best_fold_data["X_test"]
y_train = best_fold_data["y_train"]
y_test  = best_fold_data["y_test"]
train_df = best_fold_data["train_df"]
test_df  = best_fold_data["test_df"]
y_scaler = best_fold_data["y_scaler"]

print("Train/Test datasets for best fold (XGBoost) retrieved.")

# Optional: Fit XGBoost on this best fold
xgb_model = XGBRegressor(
    n_estimators=best_params.get("n_estimators", 500),
    max_depth=best_params.get("max_depth", 6),
    learning_rate=best_params.get("learning_rate", 0.1),
    subsample=best_params.get("subsample", 1.0),
    colsample_bytree=best_params.get("max_features", 1.0),
    random_state=30,
    n_jobs=-1
)

xgb_model.fit(X_train, y_train.ravel())
final_preds = xgb_model.predict(X_test)
final_preds = y_scaler.inverse_transform(final_preds.reshape(-1,1))
final_y_test = y_scaler.inverse_transform(y_test)

print("XGBoost model trained on best fold.")
# Out:
# Best Fold (XGBoost): 5
# R²: 0.9942403804815765
# MAE: 346.4103342288904
# RMSE: 680.8760316937371
# Train/Test datasets for best fold (XGBoost) retrieved.
# XGBoost model trained on best fold.

# %% [markdown]
# ## Main Code for XGBoost

# %%
# New method for objective xgb (hyper tune and add k fold in same code )
# Global variables to track the best dataset across all trials for XGBoost
best_overall_r2_xgb = -np.inf
best_overall_train_df_xgb = None
best_overall_test_df_xgb = None

def objective_xgb(trial, metrics_csv="fold_metrics_xgboost.csv"):
    global best_overall_r2_xgb, best_overall_train_df_xgb, best_overall_test_df_xgb

    # 1. Hyperparameter search space
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000),
        "max_depth": trial.suggest_int("max_depth", 3, 15),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 5),
        "reg_alpha": trial.suggest_float("reg_alpha", 0, 1),
        "reg_lambda": trial.suggest_float("reg_lambda", 0, 1),
        "random_state": 30,
        "n_jobs": -1
    }

    fold_metrics = []

    # 2. Group K-Fold CV
    for fold_data in group_kfold_split_by_date(
        df,
        date_col="DATE",
        feature_cols=features,
        target_col="AC_POWER",
        n_splits=5
    ):
        X_train = fold_data["X_train"]
        X_test  = fold_data["X_test"]
        y_train = fold_data["y_train"].ravel()
        y_test  = fold_data["y_test"].ravel()
        y_scaler = fold_data["y_scaler"]

        # 3. Build and fit XGBoost model
        model = xgb.XGBRegressor(**params)
        model.fit(
            X_train, y_train,
            eval_set=[(X_test, y_test)],
            verbose=False
        )

        # 4. Predict and inverse transform
        preds = model.predict(X_test).reshape(-1, 1)
        preds = y_scaler.inverse_transform(preds)
        real_y = y_scaler.inverse_transform(y_test.reshape(-1, 1))

        # 5. Metrics
        r2 = r2_score(real_y, preds)
        mae = mean_absolute_error(real_y, preds)
        rmse = np.sqrt(mean_squared_error(real_y, preds))

        fold_metrics.append({
            "fold": fold_data["fold"],
            "r2": r2,
            "mae": mae,
            "rmse": rmse
        })

        # Track the best fold across all trials
        if r2 > best_overall_r2_xgb:
            best_overall_r2_xgb = r2
            best_overall_train_df_xgb = fold_data["train_df"]
            best_overall_test_df_xgb  = fold_data["test_df"]

    # 6. Save fold metrics for this trial
    fold_metrics_df = pd.DataFrame(fold_metrics)
    fold_metrics_df["trial_number"] = trial.number
    fold_metrics_df.to_csv(metrics_csv, mode='a', index=False,
                           header=not pd.io.common.file_exists(metrics_csv))

    # 7. Store mean metrics in trial attributes
    mean_r2 = np.mean([m["r2"] for m in fold_metrics])
    trial.set_user_attr("mean_mae", np.mean([m["mae"] for m in fold_metrics]))
    trial.set_user_attr("mean_rmse", np.mean([m["rmse"] for m in fold_metrics]))

    return mean_r2

# %%
# Create study → Bayesian optimization for XGBoost
study_xgb = optuna.create_study(
    direction="maximize",
    sampler=optuna.samplers.TPESampler()
)

# Run optimization
study_xgb.optimize(objective_xgb, n_trials=50, show_progress_bar=True)

# Best trial
best_trial_xgb = study_xgb.best_trial

print("Best Trial Results (XGBoost)")
print("Mean R² Score across folds:", best_trial_xgb.value)
print("Mean MAE across folds :", best_trial_xgb.user_attrs["mean_mae"])
print("Mean RMSE across folds:", best_trial_xgb.user_attrs["mean_rmse"])

print("\nBest Hyperparameters:")
for k, v in best_trial_xgb.params.items():
    print(f"  {k}: {v}")

# Save the global best dataset after all trials
if best_overall_train_df_xgb is not None and best_overall_test_df_xgb is not None:
    best_overall_train_df_xgb.to_csv("best_train_dataset_xgboost.csv", index=False)
    best_overall_test_df_xgb.to_csv("best_test_dataset_xgboost.csv", index=False)
    print("Best train/test datasets saved with highest R² score:", best_overall_r2_xgb)

print("\nBest train/test datasets with highest R² across all trials saved to CSV.")
best_train_path = "best_train_dataset_xgboost.csv"
best_test_path  = "best_test_dataset_xgboost.csv"
print("Train dataset:", best_train_path)
print("Test dataset :", best_test_path)

# Optional: load it to check shape
best_train_df_xgb = pd.read_csv(best_train_path)
best_test_df_xgb  = pd.read_csv(best_test_path)
print("Train shape:", best_train_df_xgb.shape)
print("Test shape :", best_test_df_xgb.shape)
# Out:
# [I 2025-11-30 11:28:36,463] A new study created in memory with name: no-name-52805153-23f9-4565-8d68-42c3d6e8c0e9
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-11-30 11:28:36,890] Trial 0 finished with value: 0.9732263604968086 and parameters: {'n_estimators': 562, 'max_depth': 15, 'learning_rate': 0.11678349898419912, 'subsample': 0.9833376421106375, 'colsample_bytree': 0.9975195372723018, 'gamma': 2.3065794273432267, 'reg_alpha': 0.7363128870415085, 'reg_lambda': 0.7888851705415829}. Best is trial 0 with value: 0.9732263604968086.
# [I 2025-11-30 11:28:37,160] Trial 1 finished with value: 0.9632396665978927 and parameters: {'n_estimators': 361, 'max_depth': 10, 'learning_rate': 0.10022718433008455, 'subsample': 0.9871795332011932, 'colsample_bytree': 0.975912190603515, 'gamma': 3.6718103165352884, 'reg_alpha': 0.9777129635634545, 'reg_lambda': 0.2382956022074435}. Best is trial 0 with value: 0.9732263604968086.
# [I 2025-11-30 11:28:37,839] Trial 2 finished with value: 0.9872646780344448 and parameters: {'n_estimators': 869, 'max_depth': 3, 'learning_rate': 0.010413500041377302, 'subsample': 0.5181498750099357, 'colsample_bytree': 0.8908413575042328, 'gamma': 0.2404853326215567, 'reg_alpha': 0.929210694925233, 'reg_lambda': 0.18065856133974612}. Best is trial 2 with value: 0.9872646780344448.
# [I 2025-11-30 11:28:37,958] Trial 3 finished with value: 0.9544862169381769 and parameters: {'n_estimators': 111, 'max_depth': 15, 'learning_rate': 0.19897315297206633, 'subsample': 0.9116357020939009, 'colsample_bytree': 0.7646760220172882, 'gamma': 4.894267931485149, 'reg_alpha': 0.2876670301491284, 'reg_lambda': 0.4212950395389269}. Best is trial 2 with value: 0.9872646780344448.
# [I 2025-11-30 11:28:38,638] Trial 4 finished with value: 0.946945119754013 and parameters: {'n_estimators': 940, 'max_depth': 9, 'learning_rate': 0.0531253877041594, 'subsample': 0.7823163022194258, 'colsample_bytree': 0.6061106654635298, 'gamma': 1.418155957463028, 'reg_alpha': 0.7574319496328153, 'reg_lambda': 0.3414656611842013}. Best is trial 2 with value: 0.9872646780344448.
# [I 2025-11-30 11:28:38,940] Trial 5 finished with value: 0.9456311853920478 and parameters: {'n_estimators': 391, 'max_depth': 11, 'learning_rate': 0.28188027622248796, 'subsample': 0.5382657599237592, 'colsample_bytree': 0.7163027062042611, 'gamma': 4.024151739343539, 'reg_alpha': 0.8123318408181801, 'reg_lambda': 0.34236561898867557}. Best is trial 2 with value: 0.9872646780344448.
# [I 2025-11-30 11:28:39,210] Trial 6 finished with value: 0.9785652047659521 and parameters: {'n_estimators': 343, 'max_depth': 11, 'learning_rate': 0.0800629914782787, 'subsample': 0.9536474948513676, 'colsample_bytree': 0.9734374359311828, 'gamma': 1.6211993002434304, 'reg_alpha': 0.745800903662416, 'reg_lambda': 0.721596480122489}. Best is trial 2 with value: 0.9872646780344448.
# [I 2025-11-30 11:28:39,322] Trial 7 finished with value: 0.9562577056099333 and parameters: {'n_estimators': 101, 'max_depth': 6, 'learning_rate': 0.14333494410329725, 'subsample': 0.8196506028681181, 'colsample_bytree': 0.6890695683465615, 'gamma': 4.209787387437001, 'reg_alpha': 0.6005006838843338, 'reg_lambda': 0.113893339579753}. Best is trial 2 with value: 0.9872646780344448.
# [I 2025-11-30 11:28:39,859] Trial 8 finished with value: 0.9857015376744034 and parameters: {'n_estimators': 773, 'max_depth': 10, 'learning_rate': 0.1618193469648534, 'subsample': 0.6651119939242718, 'colsample_bytree': 0.8634860176937449, 'gamma': 0.5336868692068253, 'reg_alpha': 0.2353873980926311, 'reg_lambda': 0.26567465694966375}. Best is trial 2 with value: 0.9872646780344448.
# [I 2025-11-30 11:28:40,476] Trial 9 finished with value: 0.9907445962300745 and parameters: {'n_estimators': 937, 'max_depth': 6, 'learning_rate': 0.12623195226776365, 'subsample': 0.8849499282669708, 'colsample_bytree': 0.9169504330644924, 'gamma': 0.0949366619794112, 'reg_alpha': 0.9932382448189164, 'reg_lambda': 0.2254027334444827}. Best is trial 9 with value: 0.9907445962300745.
# [I 2025-11-30 11:28:41,003] Trial 10 finished with value: 0.9357174939304516 and parameters: {'n_estimators': 689, 'max_depth': 3, 'learning_rate': 0.2275258883612124, 'subsample': 0.6725961188694011, 'colsample_bytree': 0.5202189560221498, 'gamma': 2.7585494356018367, 'reg_alpha': 0.4334200016204173, 'reg_lambda': 0.590717124923665}. Best is trial 9 with value: 0.9907445962300745.
# [I 2025-11-30 11:28:41,798] Trial 11 finished with value: 0.9902986068838269 and parameters: {'n_estimators': 1000, 'max_depth': 3, 'learning_rate': 0.014788617448851293, 'subsample': 0.515357045987657, 'colsample_bytree': 0.8458227869247884, 'gamma': 0.06345825091236224, 'reg_alpha': 0.9953865417942229, 'reg_lambda': 0.02539313104238386}. Best is trial 9 with value: 0.9907445962300745.
# [I 2025-11-30 11:28:42,587] Trial 12 finished with value: 0.9900586389636932 and parameters: {'n_estimators': 982, 'max_depth': 6, 'learning_rate': 0.015017682745226251, 'subsample': 0.863669183946494, 'colsample_bytree': 0.835728698391916, 'gamma': 0.14121144304629557, 'reg_alpha': 0.9786427504597036, 'reg_lambda': 0.012931750277671425}. Best is trial 9 with value: 0.9907445962300745.
# [I 2025-11-30 11:28:43,157] Trial 13 finished with value: 0.9806535736715596 and parameters: {'n_estimators': 822, 'max_depth': 6, 'learning_rate': 0.06923671225318614, 'subsample': 0.6887615052606989, 'colsample_bytree': 0.8000153334612389, 'gamma': 1.1141493976206334, 'reg_alpha': 0.5190272253685742, 'reg_lambda': 0.02167118668189877}. Best is trial 9 with value: 0.9907445962300745.
# [I 2025-11-30 11:28:43,837] Trial 14 finished with value: 0.9822878888860529 and parameters: {'n_estimators': 995, 'max_depth': 5, 'learning_rate': 0.2120496099167845, 'subsample': 0.5946112322304926, 'colsample_bytree': 0.9094231987737866, 'gamma': 0.8798436172939584, 'reg_alpha': 0.06251485210140767, 'reg_lambda': 0.9754789283961866}. Best is trial 9 with value: 0.9907445962300745.
# [I 2025-11-30 11:28:44,333] Trial 15 finished with value: 0.9713239470665144 and parameters: {'n_estimators': 678, 'max_depth': 8, 'learning_rate': 0.29088397960650136, 'subsample': 0.7388961956772846, 'colsample_bytree': 0.9224395833779009, 'gamma': 1.994788980381521, 'reg_alpha': 0.8645081418409865, 'reg_lambda': 0.5213683250614409}. Best is trial 9 with value: 0.9907445962300745.
# [I 2025-11-30 11:28:44,945] Trial 16 finished with value: 0.9685017163482399 and parameters: {'n_estimators': 890, 'max_depth': 4, 'learning_rate': 0.15597721556499317, 'subsample': 0.8844391711527169, 'colsample_bytree': 0.8095305358983339, 'gamma': 2.9355614532651275, 'reg_alpha': 0.6330062460641477, 'reg_lambda': 0.13204179746474484}. Best is trial 9 with value: 0.9907445962300745.
# [I 2025-11-30 11:28:45,512] Trial 17 finished with value: 0.9923058620581087 and parameters: {'n_estimators': 764, 'max_depth': 7, 'learning_rate': 0.12456586306333735, 'subsample': 0.5929216983970566, 'colsample_bytree': 0.6866846735870944, 'gamma': 0.009503846690375545, 'reg_alpha': 0.8723778553502208, 'reg_lambda': 0.11253413209349301}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:46,035] Trial 18 finished with value: 0.944880439186995 and parameters: {'n_estimators': 730, 'max_depth': 8, 'learning_rate': 0.12387905204869833, 'subsample': 0.6249199474705842, 'colsample_bytree': 0.6466163820733072, 'gamma': 0.863342309242804, 'reg_alpha': 0.8419141778920286, 'reg_lambda': 0.4038197586059632}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:46,448] Trial 19 finished with value: 0.95644122754919 and parameters: {'n_estimators': 580, 'max_depth': 13, 'learning_rate': 0.1705768173126332, 'subsample': 0.7398110757514127, 'colsample_bytree': 0.5589448430515344, 'gamma': 0.5667770069715263, 'reg_alpha': 0.6469588054292601, 'reg_lambda': 0.22855194735128834}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:46,847] Trial 20 finished with value: 0.9767809788822168 and parameters: {'n_estimators': 462, 'max_depth': 7, 'learning_rate': 0.18428772628943518, 'subsample': 0.8182091671264096, 'colsample_bytree': 0.6674724192007612, 'gamma': 1.6981770445971311, 'reg_alpha': 0.42475516707243355, 'reg_lambda': 0.6169821447380973}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:47,528] Trial 21 finished with value: 0.9887011078170544 and parameters: {'n_estimators': 877, 'max_depth': 4, 'learning_rate': 0.03760354060755708, 'subsample': 0.5650929495581974, 'colsample_bytree': 0.7510669430155507, 'gamma': 0.23826217231852187, 'reg_alpha': 0.9885777116781339, 'reg_lambda': 0.08791968123775142}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:48,183] Trial 22 finished with value: 0.9902565776537022 and parameters: {'n_estimators': 804, 'max_depth': 5, 'learning_rate': 0.24028331963196492, 'subsample': 0.5051278742464813, 'colsample_bytree': 0.8573724667526004, 'gamma': 0.07378414644630969, 'reg_alpha': 0.8844396939696078, 'reg_lambda': 0.013804373135642522}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:48,879] Trial 23 finished with value: 0.9784206545658783 and parameters: {'n_estimators': 953, 'max_depth': 7, 'learning_rate': 0.0966077808290752, 'subsample': 0.6057163055110288, 'colsample_bytree': 0.9420531601472919, 'gamma': 1.1642298041745072, 'reg_alpha': 0.900392896003208, 'reg_lambda': 0.08754437759390875}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:49,405] Trial 24 finished with value: 0.98501425442709 and parameters: {'n_estimators': 651, 'max_depth': 4, 'learning_rate': 0.13066489451192703, 'subsample': 0.5614867574090623, 'colsample_bytree': 0.771432717014049, 'gamma': 0.4565635939662142, 'reg_alpha': 0.9997711498900133, 'reg_lambda': 0.31772125768489945}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:50,174] Trial 25 finished with value: 0.982601361409416 and parameters: {'n_estimators': 905, 'max_depth': 5, 'learning_rate': 0.04616710312117535, 'subsample': 0.641814419620047, 'colsample_bytree': 0.881574139996547, 'gamma': 0.7986322327790338, 'reg_alpha': 0.8034504900079422, 'reg_lambda': 0.1907437824783815}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:50,929] Trial 26 finished with value: 0.984595016328614 and parameters: {'n_estimators': 810, 'max_depth': 7, 'learning_rate': 0.09569660276940523, 'subsample': 0.7133678162010468, 'colsample_bytree': 0.8171770943113229, 'gamma': 0.6660621124380034, 'reg_alpha': 0.6892950957256992, 'reg_lambda': 0.15479476258973945}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:51,875] Trial 27 finished with value: 0.9906129985640595 and parameters: {'n_estimators': 999, 'max_depth': 3, 'learning_rate': 0.06243341005672086, 'subsample': 0.5521426062285264, 'colsample_bytree': 0.7224055309282637, 'gamma': 0.09596804836364164, 'reg_alpha': 0.9053881174776861, 'reg_lambda': 0.07948352287855642}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:52,597] Trial 28 finished with value: 0.9480078463690973 and parameters: {'n_estimators': 745, 'max_depth': 8, 'learning_rate': 0.07308455545868278, 'subsample': 0.5860455607211454, 'colsample_bytree': 0.6175048050644544, 'gamma': 1.0838036173947592, 'reg_alpha': 0.5528716607853233, 'reg_lambda': 0.4398868149786066}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:53,154] Trial 29 finished with value: 0.9727292100993497 and parameters: {'n_estimators': 582, 'max_depth': 5, 'learning_rate': 0.10523156085255038, 'subsample': 0.9291681241127119, 'colsample_bytree': 0.7282016300370924, 'gamma': 2.4298917806983784, 'reg_alpha': 0.7057086533379782, 'reg_lambda': 0.2928576244677065}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:54,001] Trial 30 finished with value: 0.9735777990046547 and parameters: {'n_estimators': 859, 'max_depth': 9, 'learning_rate': 0.12665826423041635, 'subsample': 0.7776246219000265, 'colsample_bytree': 0.6997915833241527, 'gamma': 1.9969607838796386, 'reg_alpha': 0.7928624685257788, 'reg_lambda': 0.9644472966808468}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:55,105] Trial 31 finished with value: 0.990962417429154 and parameters: {'n_estimators': 1000, 'max_depth': 3, 'learning_rate': 0.025229482785724077, 'subsample': 0.5397680450955282, 'colsample_bytree': 0.7792276837439531, 'gamma': 0.0522689889508972, 'reg_alpha': 0.916741394956043, 'reg_lambda': 0.06612755517344004}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:56,190] Trial 32 finished with value: 0.985934955703587 and parameters: {'n_estimators': 929, 'max_depth': 4, 'learning_rate': 0.0337790524025057, 'subsample': 0.5452696325687519, 'colsample_bytree': 0.643951944644919, 'gamma': 0.01107373346815338, 'reg_alpha': 0.9228249309855612, 'reg_lambda': 0.084527348818011}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:57,081] Trial 33 finished with value: 0.9865432594268139 and parameters: {'n_estimators': 945, 'max_depth': 3, 'learning_rate': 0.057746948957512825, 'subsample': 0.6331840679365889, 'colsample_bytree': 0.7916311432355827, 'gamma': 0.4473323758227008, 'reg_alpha': 0.9323189054006548, 'reg_lambda': 0.21119924747430713}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:57,904] Trial 34 finished with value: 0.9878338871808172 and parameters: {'n_estimators': 843, 'max_depth': 6, 'learning_rate': 0.08718215531674857, 'subsample': 0.5789202971467982, 'colsample_bytree': 0.9971630057037993, 'gamma': 0.3228395953901735, 'reg_alpha': 0.8497927856639549, 'reg_lambda': 0.16021603532469617}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:58,152] Trial 35 finished with value: 0.9218053775304229 and parameters: {'n_estimators': 189, 'max_depth': 3, 'learning_rate': 0.11382905693136391, 'subsample': 0.5434287441479555, 'colsample_bytree': 0.5785063431423125, 'gamma': 3.4257438224836556, 'reg_alpha': 0.9038106644029451, 'reg_lambda': 0.08235201303869964}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:59,035] Trial 36 finished with value: 0.9766512345745706 and parameters: {'n_estimators': 911, 'max_depth': 4, 'learning_rate': 0.027585301018195355, 'subsample': 0.6115088267906593, 'colsample_bytree': 0.7300078466103257, 'gamma': 1.2966124810821398, 'reg_alpha': 0.7642217101851863, 'reg_lambda': 0.2650483212315652}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:28:59,961] Trial 37 finished with value: 0.9886734637379139 and parameters: {'n_estimators': 953, 'max_depth': 13, 'learning_rate': 0.064640169891201, 'subsample': 0.9882195703910324, 'colsample_bytree': 0.676812015853135, 'gamma': 0.38052823211522624, 'reg_alpha': 0.9387967999381119, 'reg_lambda': 0.18681057308651913}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:29:00,454] Trial 38 finished with value: 0.9811936625461858 and parameters: {'n_estimators': 486, 'max_depth': 7, 'learning_rate': 0.14301090216691736, 'subsample': 0.5022174465854208, 'colsample_bytree': 0.7525741223960352, 'gamma': 0.7010670644550031, 'reg_alpha': 0.8324789598476868, 'reg_lambda': 0.050581715970353915}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:29:01,058] Trial 39 finished with value: 0.9734579415523171 and parameters: {'n_estimators': 629, 'max_depth': 10, 'learning_rate': 0.18183078778606246, 'subsample': 0.5332562365693474, 'colsample_bytree': 0.7036094808680344, 'gamma': 1.496612771597509, 'reg_alpha': 0.7124343920270628, 'reg_lambda': 0.3548050625046468}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:29:01,836] Trial 40 finished with value: 0.9832264443930521 and parameters: {'n_estimators': 768, 'max_depth': 5, 'learning_rate': 0.051379856189189124, 'subsample': 0.9520997479520535, 'colsample_bytree': 0.7755185939549282, 'gamma': 0.9567317333140682, 'reg_alpha': 0.9453535283838488, 'reg_lambda': 0.13480140879391675}. Best is trial 17 with value: 0.9923058620581087.
# [I 2025-11-30 11:29:03,004] Trial 41 finished with value: 0.9926190238473513 and parameters: {'n_estimators': 991, 'max_depth': 3, 'learning_rate': 0.014646716221084499, 'subsample': 0.5259883755764126, 'colsample_bytree': 0.8337136984745002, 'gamma': 0.0007502984096079968, 'reg_alpha': 0.9595383922801118, 'reg_lambda': 0.06689595344445792}. Best is trial 41 with value: 0.9926190238473513.
# [I 2025-11-30 11:29:04,000] Trial 42 finished with value: 0.9923866565366544 and parameters: {'n_estimators': 992, 'max_depth': 3, 'learning_rate': 0.027695697735290084, 'subsample': 0.5596630668408267, 'colsample_bytree': 0.8819860217033166, 'gamma': 0.009222515124662961, 'reg_alpha': 0.8751057326216976, 'reg_lambda': 0.06382227759277385}. Best is trial 41 with value: 0.9926190238473513.
# [I 2025-11-30 11:29:04,846] Trial 43 finished with value: 0.9880100881435542 and parameters: {'n_estimators': 873, 'max_depth': 3, 'learning_rate': 0.024156055611585805, 'subsample': 0.5265844413232158, 'colsample_bytree': 0.947009701324915, 'gamma': 0.2485647164728304, 'reg_alpha': 0.7771825718262249, 'reg_lambda': 0.23692047875026168}. Best is trial 41 with value: 0.9926190238473513.
# [I 2025-11-30 11:29:05,793] Trial 44 finished with value: 0.9925430260941337 and parameters: {'n_estimators': 964, 'max_depth': 4, 'learning_rate': 0.046134212146584516, 'subsample': 0.5743871890309152, 'colsample_bytree': 0.8758333501168557, 'gamma': 0.006577902698354163, 'reg_alpha': 0.9570742377962163, 'reg_lambda': 0.13393123271604168}. Best is trial 41 with value: 0.9926190238473513.
# [I 2025-11-30 11:29:06,712] Trial 45 finished with value: 0.942501225288861 and parameters: {'n_estimators': 965, 'max_depth': 4, 'learning_rate': 0.011311245277930036, 'subsample': 0.6533371730139803, 'colsample_bytree': 0.8854950586003619, 'gamma': 4.604997286638587, 'reg_alpha': 0.8601733168981512, 'reg_lambda': 0.7965737460541467}. Best is trial 41 with value: 0.9926190238473513.
# [I 2025-11-30 11:29:07,573] Trial 46 finished with value: 0.9842181198740697 and parameters: {'n_estimators': 910, 'max_depth': 3, 'learning_rate': 0.039104279381469854, 'subsample': 0.5715414683485623, 'colsample_bytree': 0.8272636374155119, 'gamma': 0.5863012748974985, 'reg_alpha': 0.9556292878146718, 'reg_lambda': 0.04960732770639997}. Best is trial 41 with value: 0.9926190238473513.
# [I 2025-11-30 11:29:08,395] Trial 47 finished with value: 0.988162820952186 and parameters: {'n_estimators': 839, 'max_depth': 4, 'learning_rate': 0.025045817231474, 'subsample': 0.6084812501606471, 'colsample_bytree': 0.8660650537068336, 'gamma': 0.3448976686788984, 'reg_alpha': 0.12544752509627166, 'reg_lambda': 0.12225644305127951}. Best is trial 41 with value: 0.9926190238473513.
# [I 2025-11-30 11:29:09,332] Trial 48 finished with value: 0.9923563270743463 and parameters: {'n_estimators': 968, 'max_depth': 3, 'learning_rate': 0.04167623695181351, 'subsample': 0.5205093708128632, 'colsample_bytree': 0.8979750727782375, 'gamma': 0.022575291308518347, 'reg_alpha': 0.2971222838202834, 'reg_lambda': 3.1935630803642256e-05}. Best is trial 41 with value: 0.9926190238473513.
# [I 2025-11-30 11:29:09,653] Trial 49 finished with value: 0.9490045062979586 and parameters: {'n_estimators': 278, 'max_depth': 5, 'learning_rate': 0.08274580393718553, 'subsample': 0.5007485277131135, 'colsample_bytree': 0.8976250609872506, 'gamma': 3.487926618095157, 'reg_alpha': 0.32389097814843476, 'reg_lambda': 0.009379522431592513}. Best is trial 41 with value: 0.9926190238473513.
# Best Trial Results (XGBoost)
# Mean R² Score across folds: 0.9926190238473513
# Mean MAE across folds : 383.1360045753714
# Mean RMSE across folds: 711.3768863089816
#
# Best Hyperparameters:
#   n_estimators: 991
#   max_depth: 3
#   learning_rate: 0.014646716221084499
#   subsample: 0.5259883755764126
#   colsample_bytree: 0.8337136984745002
#   gamma: 0.0007502984096079968
#   reg_alpha: 0.9595383922801118
#   reg_lambda: 0.06689595344445792
# Best train/test datasets saved with highest R² score: 0.9955332314641514
#
# Best train/test datasets with highest R² across all trials saved to CSV.
# Train dataset: best_train_dataset_xgboost.csv
# Test dataset : best_test_dataset_xgboost.csv
# Train shape: (2524, 8)
# Test shape : (658, 8)

# %%
# Get best hyperparameters from Optuna for XGBoost
best_params = best_trial_xgb.params.copy()
best_params["random_state"] = 30
best_params["n_jobs"] = -1
best_params["objective"] = "reg:squarederror"  # required for regression

# Retrieve the best fold datasets for the trial
best_train_df = pd.read_csv('best_train_dataset_xgboost.csv')
best_test_df  = pd.read_csv('best_test_dataset_xgboost.csv')

# Separate features and target
X_train = best_train_df[features].values
y_train = best_train_df["AC_POWER"].values.ravel()

X_test  = best_test_df[features].values
y_test  = best_test_df["AC_POWER"].values.ravel()

# Fit the final XGBoost model
best_xgb_model = xgb.XGBRegressor(**best_params)
best_xgb_model.fit(X_train, y_train)

# Predict on test set
final_pred_xgb = best_xgb_model.predict(X_test)

# Evaluate
final_r2 = r2_score(y_test, final_pred_xgb)
final_mae = mean_absolute_error(y_test, final_pred_xgb)
final_rmse = np.sqrt(mean_squared_error(y_test, final_pred_xgb))
y_pred_xgb = final_pred_xgb

print("Final R²:", final_r2)
print("Final MAE:", final_mae)
print("Final RMSE:", final_rmse)
# Out:
# Final R²: 0.9960196949526572
# Final MAE: 312.0711438427135
# Final RMSE: 566.016807680775

# %% [markdown]
# ### Graphical Analysis

# %%
plt.figure(figsize=(5,5))
plt.scatter(y_test, y_pred_xgb, s=10, alpha=0.4)
lo, hi = min(np.min(y_test), np.min(y_pred_xgb)), max(np.max(y_test), np.max(y_pred_xgb))
plt.plot([lo, hi], [lo, hi], 'r--', lw=2, label='Ideal y=x')
plt.xlabel('Actual (y_test)'); plt.ylabel('Predicted (y_pred)')
plt.title('Predicted vs Actual for random forest model '); plt.legend(); plt.tight_layout();
plt.show()

# %%
# Ensuring y_test and y_pred are both 1D arrays of same length
y_test_aligned = np.array(y_test).flatten()
y_pred_aligned = np.array(y_pred_xgb).flatten()

# Compute residuals
residuals = y_test_aligned - y_pred_aligned

# Residual plot
plt.figure(figsize=(6,5))
plt.scatter(y_pred_aligned, residuals, alpha=0.5, s=15, color='purple')
plt.axhline(0, color='red', linestyle='--', lw=2)  # horizontal line at 0
plt.xlabel('Predicted Values')
plt.ylabel('Residuals (y_test - y_pred)')
plt.title('Residual Plot for RandomForest Model')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.plot(y_test, label='True')
plt.plot(y_pred_xgb, label='Predicted')
plt.legend()
plt.title('Model Predictions vs True AC POWER Kw')
plt.xlabel('Time Step')
plt.ylabel('AC_POWER (kW)')
plt.show()

# %% [markdown]
# Learning Rate Curve

# %%
# Create DMatrices
dtrain = DMatrix(X_train, label=y_train)
dtest = DMatrix(X_test, label=y_test)

# Get booster
booster = best_xgb_model.get_booster()

# Use the number of trees from the model's n_estimators
n_trees = best_xgb_model.n_estimators

# Calculate train/test RMSE per iteration
train_rmse = []
test_rmse  = []

for i in range(n_trees):
    train_pred = booster.predict(dtrain, iteration_range=(0, i+1))
    test_pred  = booster.predict(dtest, iteration_range=(0, i+1))
    
    train_rmse.append(np.sqrt(np.mean((y_train - train_pred)**2)))
    test_rmse.append(np.sqrt(np.mean((y_test - test_pred)**2)))

# Plot
plt.figure(figsize=(10,6))
plt.plot(train_rmse, label='Train RMSE', color='blue')
plt.plot(test_rmse, label='Test RMSE', color='red')
plt.xlabel('Boosting Round')
plt.ylabel('RMSE')
plt.title('XGBoost Learning Curve (Existing Model)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The groupkfold split function that we wrote we can also use that function in here.

# %% [markdown]
# ### Statistical Analysis For XGBoost

# %%
# 1. Load fold metrics CSV

metrics_csv = "fold_metrics_xgboost.csv"  # Change if needed
metrics_df_xgboost = pd.read_csv(metrics_csv)

# %%
# Describe 
desc_stats_xgboost = metrics_df_xgboost[['r2','mae','rmse']].describe()
desc_stats_xgboost
# Out:
#                r2          mae         rmse
# count  250.000000   250.000000   250.000000
# mean     0.975278   906.501200  1259.586016
# std      0.018062   373.884593   457.948410
# min      0.911756   348.622634   599.608627
# 25%      0.968793   612.375318   922.903425
# 50%      0.981824   838.206320  1138.597202
# 75%      0.988626  1139.612760  1528.466265
# max      0.995533  1947.331861  2512.072699

# %%
fold_stats_xgboost = metrics_df_xgboost.groupby('fold')[['r2','mae','rmse']].agg(['mean','std','min','max'])
fold_stats_xgboost
# Out:
#             r2                                       mae              \
#           mean       std       min       max        mean         std
# fold
# 1     0.970623  0.019069  0.911756  0.986843  913.785655  337.811810
# 2     0.975277  0.016078  0.928457  0.991209  888.637420  342.256237
# 3     0.975890  0.018563  0.921906  0.994695  903.362349  392.872303
# 4     0.978813  0.017443  0.925310  0.995412  891.053786  396.181898
# 5     0.975788  0.018742  0.921599  0.995533  935.666791  407.791174
#
#                                       rmse                          \
#              min          max         mean         std         min
# fold
# 1     435.857798  1769.278842  1300.449327  389.944505  907.837999
# 2     399.278037  1689.364825  1241.216672  390.784597  775.281204
# 3     351.456893  1843.253474  1245.572016  485.912618  626.337684
# 4     369.564834  1894.237782  1211.471568  502.432906  609.416537
# 5     348.622634  1947.331861  1299.220497  515.917093  599.608627
#
#
#               max
# fold
# 1     2351.094097
# 2     2211.652989
# 3     2403.059361
# 4     2458.880429
# 5     2512.072699

# %%
# Visualize
sns.set(style="whitegrid")

# Boxplots
plt.figure(figsize=(12,5))
plt.subplot(1,3,1)
sns.boxplot(x='fold', y='r2', data=metrics_df_xgboost)
plt.title('R² per Fold')

plt.subplot(1,3,2)
sns.boxplot(x='fold', y='mae', data=metrics_df_xgboost)
plt.title('MAE per Fold')

plt.subplot(1,3,3)
sns.boxplot(x='fold', y='rmse', data=metrics_df_xgboost)
plt.title('RMSE per Fold')

plt.tight_layout()
plt.show()

# %%
# Line plots: metric trend across trials
plt.figure(figsize=(12,4))
sns.lineplot(x='trial_number', y='r2', hue='fold', data=metrics_df_xgboost, marker='o')
plt.title("R² across Trials per Fold")
plt.xlabel("Trial Number")
plt.ylabel("R²")
plt.show()

# %%
# Have to do paired test for different fold
# Example: ANOVA to check if R² differs significantly between folds
fold_r2_groups = [metrics_df_xgboost[metrics_df_xgboost['fold']==f]['r2'] for f in metrics_df_xgboost['fold'].unique()]
anova_result = f_oneway(*fold_r2_groups)
print("\nANOVA for R² across folds")
print(f"F-statistic: {anova_result.statistic:.4f}, p-value: {anova_result.pvalue:.4f}")

# Paired t-test example: fold 1 vs fold 2 R²
t_stat, p_val = ttest_rel(metrics_df_xgboost[metrics_df_xgboost['fold']==1]['r2'].values,
                          metrics_df_xgboost[metrics_df_xgboost['fold']==2]['r2'].values)
print("\nPaired t-test Fold 1 vs Fold 2 R²:")
print(f"t-statistic: {t_stat:.4f}, p-value: {p_val:.4f}")
# Out:
# ANOVA for R² across folds
# F-statistic: 1.3407, p-value: 0.2554
#
# Paired t-test Fold 1 vs Fold 2 R²:
# t-statistic: -7.6313, p-value: 0.0000

# %%
# 7. Confidence intervals
def compute_ci(data, confidence=0.95):
    mean = np.mean(data)
    sem  = stats.sem(data)
    ci_lower, ci_upper = stats.t.interval(confidence, len(data)-1, loc=mean, scale=sem)
    return mean, ci_lower, ci_upper

print("\n95% Confidence Intervals ")
for metric in ['r2','mae','rmse']:
    mean, ci_lower, ci_upper = compute_ci(metrics_df_xgboost[metric])
    print(f"{metric}: Mean={mean:.4f}, 95% CI=({ci_lower:.4f}, {ci_upper:.4f})")
# Out:
# 95% Confidence Intervals
# r2: Mean=0.9753, 95% CI=(0.9730, 0.9775)
# mae: Mean=906.5012, 95% CI=(859.9285, 953.0739)
# rmse: Mean=1259.5860, 95% CI=(1202.5419, 1316.6301)

# %% [markdown]
# ## Feed Forward Neural Network

# %% [markdown]
# * The plot shows AC Power as the output and Temperature/Irradiation as inputs. The relationships appear nonlinear.
# * Ambient temperature and module temperature have overlapping but distinct patterns.
# * Irradiation seems to have a strong positive correlation with AC power, but the spread suggests nonlinear effects.
# * FNNs excel at capturing complex nonlinear relationships between inputs and outputs without requiring explicit feature engineering.
#
# The relationship is strongly positive but nonlinear, and it is also a time series data set in which a feed-forward neural network performs better.
# For this part we will use pytorch library to use feed forward neural network and train it.

# %% [markdown]
# ## The Code and Innovation

# %% [markdown]
# As a part of innovation we will create a neural network with the help of pytorch library then from there we will do prediction and analysis. We will also hypertune with different activation functions to find the best result

# %%
# Device detection 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %%
# Global trackers
best_overall_r2_nn = -np.inf
best_overall_train_df_nn = None
best_overall_test_df_nn = None
# Function to get activation function layer
def get_activation(name: str):
    if name == "relu":
        return nn.ReLU()
    elif name == "sigmoid":
        return nn.Sigmoid()
    elif name == "tanh":
        return nn.Tanh()
    elif name == "leaky_relu":
        return nn.LeakyReLU()
    else:
        raise ValueError(f"Unknown activation function: {name}")

# %%
# This is our main model which is feed forward neural network
class FeedForwardNN(nn.Module):
    def __init__(self, input_dim, hidden_dim, hidden_layers, dropout, activation_name):
        super().__init__()
        layers = []

        activation_layer = get_activation(activation_name)

        # First hidden layer
        layers.append(nn.Linear(input_dim, hidden_dim))
        layers.append(activation_layer)
        layers.append(nn.Dropout(dropout))

        # Additional hidden layers
        for _ in range(hidden_layers - 1):
            layers.append(nn.Linear(hidden_dim, hidden_dim))
            layers.append(get_activation(activation_name))
            layers.append(nn.Dropout(dropout))

        # Output layer
        layers.append(nn.Linear(hidden_dim, 1))

        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# For hyper parameter tuning we will use a bunch of features which includes activation function , learning rate , hidden layers

# %%
# Optuna objective
def objective_nn(trial, metrics_csv="fold_metrics_nn.csv"):
    global best_overall_r2_nn, best_overall_train_df_nn, best_overall_test_df_nn

    # Add activation function as hyperparameter
    params = {
        "hidden_dim": trial.suggest_int("hidden_dim", 32, 512),
        "hidden_layers": trial.suggest_int("hidden_layers", 1, 5),
        "dropout": trial.suggest_float("dropout", 0.0, 0.5),
        "activation": trial.suggest_categorical("activation", ["relu", "sigmoid", "tanh", "leaky_relu"]),
        "learning_rate": trial.suggest_float("learning_rate", 1e-5, 5e-3),
        "batch_size": trial.suggest_categorical("batch_size", [64, 128, 256, 512]),
        "epochs": trial.suggest_int("epochs", 20, 200)
    }

    fold_metrics = []

    # Group K-Fold
    for fold_data in group_kfold_split_by_date(
        df,
        date_col="DATE",
        feature_cols=features,
        target_col="AC_POWER",
        n_splits=5
    ):
        # Extract
        X_train = fold_data["X_train"]
        X_test  = fold_data["X_test"]
        y_train = fold_data["y_train"].ravel()
        y_test  = fold_data["y_test"].ravel()
        y_scaler = fold_data["y_scaler"]

        # Convert to tensors
        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).view(-1,1).to(device)
        X_test_t  = torch.tensor(X_test, dtype=torch.float32).to(device)

        # DataLoader
        train_ds = TensorDataset(X_train_t, y_train_t)
        train_loader = DataLoader(train_ds, batch_size=params["batch_size"], shuffle=True)

        # Build model
        model = FeedForwardNN(
            input_dim=X_train.shape[1],
            hidden_dim=params["hidden_dim"],
            hidden_layers=params["hidden_layers"],
            dropout=params["dropout"],
            activation_name=params["activation"]
        ).to(device)

        optimizer = optim.Adam(model.parameters(), lr=params["learning_rate"])
        loss_fn = nn.MSELoss()

        # Training loop
        model.train()
        for epoch in range(params["epochs"]):
            for xb, yb in train_loader:
                optimizer.zero_grad()
                preds = model(xb)
                loss = loss_fn(preds, yb)
                loss.backward()
                optimizer.step()

        # Prediction
        model.eval()
        with torch.no_grad():
            preds = model(X_test_t).cpu().numpy().reshape(-1,1)

        # Inverse scaling
        preds = y_scaler.inverse_transform(preds)
        real_y = y_scaler.inverse_transform(y_test.reshape(-1,1))

        # Metrics
        r2 = r2_score(real_y, preds)
        mae = mean_absolute_error(real_y, preds)
        rmse = np.sqrt(mean_squared_error(real_y, preds))

        fold_metrics.append({
            "fold": fold_data["fold"],
            "r2": r2,
            "mae": mae,
            "rmse": rmse
        })

        # Save best
        if r2 > best_overall_r2_nn:
            best_overall_r2_nn = r2
            best_overall_train_df_nn = fold_data["train_df"]
            best_overall_test_df_nn  = fold_data["test_df"]

    # Save CSV
    fold_metrics_df = pd.DataFrame(fold_metrics)
    fold_metrics_df["trial_number"] = trial.number
    fold_metrics_df.to_csv(metrics_csv, mode='a', index=False,
                           header=not pd.io.common.file_exists(metrics_csv))

    mean_r2 = np.mean([m["r2"] for m in fold_metrics])

    trial.set_user_attr("mean_mae", np.mean([m["mae"] for m in fold_metrics]))
    trial.set_user_attr("mean_rmse", np.mean([m["rmse"] for m in fold_metrics]))

    return mean_r2

# %%
# Create study  Bayesian optimization for Neural Network
study_nn = optuna.create_study(
    direction="maximize",
    sampler=optuna.samplers.TPESampler()
)

# Run optimization
study_nn.optimize(objective_nn, n_trials=50, show_progress_bar=True)

# Best trial
best_trial_nn = study_nn.best_trial

print("Best Trial Results (Neural Network)")
print("Mean R² Score across folds:", best_trial_nn.value)
print("Mean MAE across folds :", best_trial_nn.user_attrs["mean_mae"])
print("Mean RMSE across folds:", best_trial_nn.user_attrs["mean_rmse"])

print("\nBest Hyperparameters:")
for k, v in best_trial_nn.params.items():
    print(f"  {k}: {v}")

# Save the global best dataset after all trials
if best_overall_train_df_nn is not None and best_overall_test_df_nn is not None:
    best_overall_train_df_nn.to_csv("best_train_dataset_neural_network.csv", index=False)
    best_overall_test_df_nn.to_csv("best_test_dataset_neural_network.csv", index=False)
    print("Best train/test datasets saved with highest R² score:", best_overall_r2_nn)

print("\nBest train/test datasets with highest R² across all NN trials saved to CSV.")
best_train_path_nn = "best_train_dataset_neural_network.csv"
best_test_path_nn  = "best_test_dataset_neural_network.csv"
print("Train dataset:", best_train_path_nn)
print("Test dataset :", best_test_path_nn)

# Optional: load it to check shape
best_train_df_nn = pd.read_csv(best_train_path_nn)
best_test_df_nn  = pd.read_csv(best_test_path_nn)
print("Train shape:", best_train_df_nn.shape)
print("Test shape :", best_test_df_nn.shape)
# Out:
# [I 2025-11-30 14:27:34,603] A new study created in memory with name: no-name-640a49ce-5b85-4a5e-9420-c3d055b33fa9
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-11-30 14:30:20,152] Trial 0 finished with value: 0.989279207491192 and parameters: {'hidden_dim': 467, 'hidden_layers': 5, 'dropout': 0.4523506832387994, 'activation': 'leaky_relu', 'learning_rate': 0.0037329629919278778, 'batch_size': 512, 'epochs': 118}. Best is trial 0 with value: 0.989279207491192.
# [I 2025-11-30 14:31:23,836] Trial 1 finished with value: 0.973122317953423 and parameters: {'hidden_dim': 214, 'hidden_layers': 3, 'dropout': 0.2772547687792855, 'activation': 'relu', 'learning_rate': 0.0003816762508789389, 'batch_size': 64, 'epochs': 77}. Best is trial 0 with value: 0.989279207491192.
# [I 2025-11-30 14:31:37,835] Trial 2 finished with value: 0.9832643442392213 and parameters: {'hidden_dim': 293, 'hidden_layers': 2, 'dropout': 0.38741518421209276, 'activation': 'relu', 'learning_rate': 0.00267463601523824, 'batch_size': 256, 'epochs': 33}. Best is trial 0 with value: 0.989279207491192.
# [I 2025-11-30 14:32:05,388] Trial 3 finished with value: 0.9891153694874291 and parameters: {'hidden_dim': 442, 'hidden_layers': 4, 'dropout': 0.11839410214730439, 'activation': 'leaky_relu', 'learning_rate': 0.0010313834221382634, 'batch_size': 512, 'epochs': 32}. Best is trial 0 with value: 0.989279207491192.
# [I 2025-11-30 14:33:28,775] Trial 4 finished with value: 0.9431491875476301 and parameters: {'hidden_dim': 203, 'hidden_layers': 5, 'dropout': 0.355084455076123, 'activation': 'leaky_relu', 'learning_rate': 0.0004228170943726863, 'batch_size': 256, 'epochs': 129}. Best is trial 0 with value: 0.989279207491192.
# [I 2025-11-30 14:38:32,658] Trial 5 finished with value: 0.989181683540985 and parameters: {'hidden_dim': 405, 'hidden_layers': 5, 'dropout': 0.436927080250797, 'activation': 'relu', 'learning_rate': 0.002505717175755817, 'batch_size': 128, 'epochs': 174}. Best is trial 0 with value: 0.989279207491192.
# [I 2025-11-30 14:39:18,618] Trial 6 finished with value: 0.9937550969653554 and parameters: {'hidden_dim': 395, 'hidden_layers': 2, 'dropout': 0.18343193997387375, 'activation': 'leaky_relu', 'learning_rate': 0.0018918657053260072, 'batch_size': 256, 'epochs': 95}. Best is trial 6 with value: 0.9937550969653554.
# [I 2025-11-30 14:39:24,464] Trial 7 finished with value: 0.9931683311826791 and parameters: {'hidden_dim': 486, 'hidden_layers': 1, 'dropout': 0.009126086962259305, 'activation': 'tanh', 'learning_rate': 0.003830629595379058, 'batch_size': 256, 'epochs': 22}. Best is trial 6 with value: 0.9937550969653554.
# [I 2025-11-30 14:39:56,080] Trial 8 finished with value: 0.9793153215520534 and parameters: {'hidden_dim': 63, 'hidden_layers': 5, 'dropout': 0.27035031979563734, 'activation': 'relu', 'learning_rate': 0.0019809056690472462, 'batch_size': 256, 'epochs': 98}. Best is trial 6 with value: 0.9937550969653554.
# [I 2025-11-30 14:40:13,026] Trial 9 finished with value: 0.9936051404831939 and parameters: {'hidden_dim': 140, 'hidden_layers': 1, 'dropout': 0.009509709495053809, 'activation': 'leaky_relu', 'learning_rate': 0.0023622227133078206, 'batch_size': 256, 'epochs': 93}. Best is trial 6 with value: 0.9937550969653554.
# [I 2025-11-30 14:42:50,293] Trial 10 finished with value: 0.9887637289960433 and parameters: {'hidden_dim': 343, 'hidden_layers': 3, 'dropout': 0.1558996096489551, 'activation': 'sigmoid', 'learning_rate': 0.004725769601699313, 'batch_size': 128, 'epochs': 198}. Best is trial 6 with value: 0.9937550969653554.
# [I 2025-11-30 14:43:03,232] Trial 11 finished with value: 0.99416861885845 and parameters: {'hidden_dim': 77, 'hidden_layers': 1, 'dropout': 0.0005214732685307755, 'activation': 'leaky_relu', 'learning_rate': 0.0018603156378349632, 'batch_size': 256, 'epochs': 66}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:43:34,262] Trial 12 finished with value: 0.9897063677409239 and parameters: {'hidden_dim': 33, 'hidden_layers': 2, 'dropout': 0.14712303437376714, 'activation': 'leaky_relu', 'learning_rate': 0.0014595642320404823, 'batch_size': 64, 'epochs': 76}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:43:58,200] Trial 13 finished with value: 0.9860868924644057 and parameters: {'hidden_dim': 329, 'hidden_layers': 2, 'dropout': 0.08363662109863661, 'activation': 'sigmoid', 'learning_rate': 0.0014219261487513125, 'batch_size': 256, 'epochs': 54}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:44:27,640] Trial 14 finished with value: 0.9933225326075718 and parameters: {'hidden_dim': 116, 'hidden_layers': 1, 'dropout': 0.202170168426972, 'activation': 'tanh', 'learning_rate': 0.0030395086888908166, 'batch_size': 256, 'epochs': 146}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:44:55,998] Trial 15 finished with value: 0.9921516698796966 and parameters: {'hidden_dim': 368, 'hidden_layers': 2, 'dropout': 0.21599254599805956, 'activation': 'leaky_relu', 'learning_rate': 0.0018463286846000342, 'batch_size': 256, 'epochs': 62}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:46:17,968] Trial 16 finished with value: 0.9916675017667389 and parameters: {'hidden_dim': 246, 'hidden_layers': 3, 'dropout': 0.06867413343794254, 'activation': 'leaky_relu', 'learning_rate': 0.0010416920344141901, 'batch_size': 128, 'epochs': 145}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:46:31,919] Trial 17 finished with value: 0.9930237930662423 and parameters: {'hidden_dim': 142, 'hidden_layers': 1, 'dropout': 0.3405960962476865, 'activation': 'leaky_relu', 'learning_rate': 0.003296021740726609, 'batch_size': 64, 'epochs': 54}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:47:13,427] Trial 18 finished with value: 0.9939363791647237 and parameters: {'hidden_dim': 403, 'hidden_layers': 2, 'dropout': 0.07831789712352503, 'activation': 'tanh', 'learning_rate': 0.0020381321320092323, 'batch_size': 512, 'epochs': 101}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:48:13,894] Trial 19 finished with value: 0.9936652195082644 and parameters: {'hidden_dim': 263, 'hidden_layers': 4, 'dropout': 0.043676609400081876, 'activation': 'tanh', 'learning_rate': 0.0008837046729212302, 'batch_size': 512, 'epochs': 120}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:48:33,785] Trial 20 finished with value: 0.9932054328991695 and parameters: {'hidden_dim': 512, 'hidden_layers': 1, 'dropout': 0.10579181047984851, 'activation': 'tanh', 'learning_rate': 0.004557284913413381, 'batch_size': 512, 'epochs': 75}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:49:18,143] Trial 21 finished with value: 0.9937823668414435 and parameters: {'hidden_dim': 403, 'hidden_layers': 2, 'dropout': 0.1736511085154307, 'activation': 'tanh', 'learning_rate': 0.002028873746515413, 'batch_size': 512, 'epochs': 102}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:50:06,022] Trial 22 finished with value: 0.9939964577030626 and parameters: {'hidden_dim': 435, 'hidden_layers': 2, 'dropout': 0.044809286148398866, 'activation': 'tanh', 'learning_rate': 0.0021945282333210264, 'batch_size': 512, 'epochs': 108}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:50:59,074] Trial 23 finished with value: 0.9937629897190534 and parameters: {'hidden_dim': 436, 'hidden_layers': 3, 'dropout': 0.04415192062854652, 'activation': 'tanh', 'learning_rate': 0.00287450955031386, 'batch_size': 512, 'epochs': 84}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:51:43,806] Trial 24 finished with value: 0.993390576271489 and parameters: {'hidden_dim': 303, 'hidden_layers': 2, 'dropout': 0.008944254454853806, 'activation': 'tanh', 'learning_rate': 0.0014406495922584185, 'batch_size': 512, 'epochs': 139}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:52:08,121] Trial 25 finished with value: 0.9933228525813831 and parameters: {'hidden_dim': 350, 'hidden_layers': 1, 'dropout': 0.05987759892899932, 'activation': 'tanh', 'learning_rate': 0.0022970472095600503, 'batch_size': 512, 'epochs': 112}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:52:17,811] Trial 26 finished with value: 0.9787123957340731 and parameters: {'hidden_dim': 189, 'hidden_layers': 1, 'dropout': 0.11711714951946786, 'activation': 'sigmoid', 'learning_rate': 0.003394983938557789, 'batch_size': 512, 'epochs': 55}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:52:47,673] Trial 27 finished with value: 0.9939992871341143 and parameters: {'hidden_dim': 91, 'hidden_layers': 2, 'dropout': 0.001508459581332347, 'activation': 'tanh', 'learning_rate': 0.001626768665886764, 'batch_size': 512, 'epochs': 160}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:54:12,212] Trial 28 finished with value: 0.9940224407759637 and parameters: {'hidden_dim': 88, 'hidden_layers': 3, 'dropout': 0.003786448051670159, 'activation': 'tanh', 'learning_rate': 0.0007456794589464791, 'batch_size': 64, 'epochs': 164}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:55:57,819] Trial 29 finished with value: 0.9420612149119478 and parameters: {'hidden_dim': 84, 'hidden_layers': 4, 'dropout': 0.480930190602515, 'activation': 'sigmoid', 'learning_rate': 0.0001892208111718771, 'batch_size': 64, 'epochs': 165}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:57:24,209] Trial 30 finished with value: 0.9927212851414844 and parameters: {'hidden_dim': 98, 'hidden_layers': 3, 'dropout': 0.028390970735152166, 'activation': 'tanh', 'learning_rate': 0.0007034738185514567, 'batch_size': 64, 'epochs': 165}. Best is trial 11 with value: 0.99416861885845.
# [I 2025-11-30 14:58:49,915] Trial 31 finished with value: 0.9942838014099434 and parameters: {'hidden_dim': 44, 'hidden_layers': 3, 'dropout': 0.0022924140847316475, 'activation': 'tanh', 'learning_rate': 0.0014385069197615811, 'batch_size': 64, 'epochs': 187}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:00:34,499] Trial 32 finished with value: 0.9940217713356938 and parameters: {'hidden_dim': 40, 'hidden_layers': 3, 'dropout': 0.0012810525833616903, 'activation': 'tanh', 'learning_rate': 0.001589577354881219, 'batch_size': 64, 'epochs': 199}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:02:20,475] Trial 33 finished with value: 0.9925357289005978 and parameters: {'hidden_dim': 39, 'hidden_layers': 4, 'dropout': 0.0983581906686366, 'activation': 'tanh', 'learning_rate': 0.0012609795340460836, 'batch_size': 64, 'epochs': 189}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:04:34,111] Trial 34 finished with value: 0.9936334931711646 and parameters: {'hidden_dim': 159, 'hidden_layers': 3, 'dropout': 0.031554181924967034, 'activation': 'relu', 'learning_rate': 0.0008138660641647465, 'batch_size': 64, 'epochs': 184}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:06:25,877] Trial 35 finished with value: 0.993452506842004 and parameters: {'hidden_dim': 55, 'hidden_layers': 4, 'dropout': 0.13395981853699465, 'activation': 'tanh', 'learning_rate': 0.0005478574830509713, 'batch_size': 64, 'epochs': 198}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:08:00,277] Trial 36 finished with value: 0.9929683714996168 and parameters: {'hidden_dim': 71, 'hidden_layers': 3, 'dropout': 0.3106548019982635, 'activation': 'tanh', 'learning_rate': 9.533516045715895e-05, 'batch_size': 64, 'epochs': 181}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:09:36,118] Trial 37 finished with value: 0.9933227720465936 and parameters: {'hidden_dim': 114, 'hidden_layers': 3, 'dropout': 0.06804373288151887, 'activation': 'relu', 'learning_rate': 0.0016471856910773013, 'batch_size': 64, 'epochs': 156}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:11:49,120] Trial 38 finished with value: 0.9931192323555844 and parameters: {'hidden_dim': 169, 'hidden_layers': 4, 'dropout': 0.026647103476516033, 'activation': 'leaky_relu', 'learning_rate': 0.001156103133350675, 'batch_size': 64, 'epochs': 172}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:14:25,389] Trial 39 finished with value: 0.9932976518122427 and parameters: {'hidden_dim': 233, 'hidden_layers': 3, 'dropout': 0.411039364343841, 'activation': 'tanh', 'learning_rate': 0.0004621149307888981, 'batch_size': 64, 'epochs': 191}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:16:20,950] Trial 40 finished with value: 0.9934676821004119 and parameters: {'hidden_dim': 122, 'hidden_layers': 4, 'dropout': 0.0010276888019705329, 'activation': 'leaky_relu', 'learning_rate': 0.0017025386298670218, 'batch_size': 64, 'epochs': 176}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:17:13,046] Trial 41 finished with value: 0.9940559018886834 and parameters: {'hidden_dim': 87, 'hidden_layers': 3, 'dropout': 0.00734904132302225, 'activation': 'tanh', 'learning_rate': 0.0017298865639953586, 'batch_size': 128, 'epochs': 155}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:17:51,798] Trial 42 finished with value: 0.9933002645288989 and parameters: {'hidden_dim': 50, 'hidden_layers': 3, 'dropout': 0.029151982585954958, 'activation': 'tanh', 'learning_rate': 0.0025988488594723483, 'batch_size': 128, 'epochs': 130}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:18:58,754] Trial 43 finished with value: 0.9940542515741692 and parameters: {'hidden_dim': 82, 'hidden_layers': 3, 'dropout': 0.050602886527292286, 'activation': 'tanh', 'learning_rate': 0.001213947698205949, 'batch_size': 128, 'epochs': 200}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:20:09,180] Trial 44 finished with value: 0.990604391564028 and parameters: {'hidden_dim': 76, 'hidden_layers': 5, 'dropout': 0.057395178229733126, 'activation': 'relu', 'learning_rate': 0.001273939692006236, 'batch_size': 128, 'epochs': 154}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:21:10,816] Trial 45 finished with value: 0.993025732643774 and parameters: {'hidden_dim': 104, 'hidden_layers': 3, 'dropout': 0.09368028403833654, 'activation': 'tanh', 'learning_rate': 0.0009588363478868318, 'batch_size': 128, 'epochs': 171}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:22:27,860] Trial 46 finished with value: 0.9917805395622852 and parameters: {'hidden_dim': 138, 'hidden_layers': 3, 'dropout': 0.024161468970912606, 'activation': 'sigmoid', 'learning_rate': 0.001837714062865876, 'batch_size': 128, 'epochs': 188}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:22:35,574] Trial 47 finished with value: 0.990988041423504 and parameters: {'hidden_dim': 66, 'hidden_layers': 3, 'dropout': 0.05647848267627231, 'activation': 'leaky_relu', 'learning_rate': 0.0006520390816937042, 'batch_size': 128, 'epochs': 24}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:24:31,159] Trial 48 finished with value: 0.9921221336407238 and parameters: {'hidden_dim': 195, 'hidden_layers': 4, 'dropout': 0.12735961956724054, 'activation': 'tanh', 'learning_rate': 0.0012060920425798292, 'batch_size': 128, 'epochs': 180}. Best is trial 31 with value: 0.9942838014099434.
# [I 2025-11-30 15:25:15,111] Trial 49 finished with value: 0.9607336142913987 and parameters: {'hidden_dim': 130, 'hidden_layers': 3, 'dropout': 0.2475127164670565, 'activation': 'leaky_relu', 'learning_rate': 0.0002626692351861185, 'batch_size': 256, 'epochs': 133}. Best is trial 31 with value: 0.9942838014099434.
# Best Trial Results (Neural Network)
# Mean R² Score across folds: 0.9942838014099434
# Mean MAE across folds : 316.63106567010993
# Mean RMSE across folds: 613.2076635969977
#
# Best Hyperparameters:
#   hidden_dim: 44
#   hidden_layers: 3
#   dropout: 0.0022924140847316475
#   activation: tanh
#   learning_rate: 0.0014385069197615811
#   batch_size: 64
#   epochs: 187
# Best train/test datasets saved with highest R² score: 0.997097555149028
#
# Best train/test datasets with highest R² across all NN trials saved to CSV.
# Train dataset: best_train_dataset_neural_network.csv
# Test dataset : best_test_dataset_neural_network.csv
# Train shape: (2524, 8)
# Test shape : (658, 8)

# %%
# Prediction on the neural network that we have developed

# Loading best hyperparameters

best_params_nn = best_trial_nn.params.copy()

hidden_dim     = best_params_nn["hidden_dim"]
hidden_layers  = best_params_nn["hidden_layers"]
dropout        = best_params_nn["dropout"]
activation     = best_params_nn["activation"]
learning_rate  = best_params_nn["learning_rate"]
batch_size     = best_params_nn["batch_size"]
epochs         = best_params_nn["epochs"]

# Load best train/test dataset

best_train_df = pd.read_csv("best_train_dataset_neural_network.csv")
best_test_df  = pd.read_csv("best_test_dataset_neural_network.csv")

X_train = best_train_df[features].values
y_train = best_train_df["AC_POWER"].values.ravel()

X_test  = best_test_df[features].values
y_test  = best_test_df["AC_POWER"].values.ravel()


# Scaling target (use same scaler as training system)

y_scaler = MinMaxScaler()
y_train_scaled = y_scaler.fit_transform(y_train.reshape(-1, 1))


# Convert to PyTorch tensors

X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
y_train_t = torch.tensor(y_train_scaled, dtype=torch.float32).to(device)

X_test_t  = torch.tensor(X_test, dtype=torch.float32).to(device)

train_ds = TensorDataset(X_train_t, y_train_t)
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)


# Build final NN model

final_nn_model = FeedForwardNN(
    input_dim=X_train.shape[1],
    hidden_dim=hidden_dim,
    hidden_layers=hidden_layers,
    dropout=dropout,
    activation_name=activation
).to(device)

optimizer = optim.Adam(final_nn_model.parameters(), lr=learning_rate)
loss_fn = nn.MSELoss()


# Training loop

final_nn_model.train()
for epoch in range(epochs):
    for xb, yb in train_loader:
        optimizer.zero_grad()
        preds = final_nn_model(xb)
        loss = loss_fn(preds, yb)
        loss.backward()
        optimizer.step()


# Prediction

final_nn_model.eval()
with torch.no_grad():
    preds_scaled = final_nn_model(X_test_t).cpu().numpy().reshape(-1, 1)


# Inverse scaling back to original values

final_pred_nn = y_scaler.inverse_transform(preds_scaled)


# Evaluate performance

final_r2   = r2_score(y_test, final_pred_nn)
final_mae  = mean_absolute_error(y_test, final_pred_nn)
final_rmse = np.sqrt(mean_squared_error(y_test, final_pred_nn))

print("Final Neural Network R² :", final_r2)
print("Final Neural Network MAE:", final_mae)
print("Final Neural Network RMSE:", final_rmse)
# Out:
# Final Neural Network R² : 0.9945777131943807
# Final Neural Network MAE: 555.635955916853
# Final Neural Network RMSE: 660.6362367579444

# %% [markdown]
# ### Graphical Analysis

# %%
# Scatter Plot: Predicted vs Actual

plt.figure(figsize=(5,5))
plt.scatter(y_test, final_pred_nn, s=10, alpha=0.4)
lo, hi = min(np.min(y_test), np.min(final_pred_nn)), max(np.max(y_test), np.max(final_pred_nn))
plt.plot([lo, hi], [lo, hi], 'r--', lw=2, label='Ideal y=x')
plt.xlabel('Actual (y_test)')
plt.ylabel('Predicted (y_pred)')
plt.title('Predicted vs Actual for Feedforward NN Model')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Residual Plot
y_test_aligned = np.array(y_test).flatten()
y_pred_aligned = np.array(final_pred_nn).flatten()

residuals = y_test_aligned - y_pred_aligned

plt.figure(figsize=(6,5))
plt.scatter(y_pred_aligned, residuals, alpha=0.5, s=15, color='purple')
plt.axhline(0, color='red', linestyle='--', lw=2)
plt.xlabel('Predicted Values')
plt.ylabel('Residuals (y_test - y_pred)')
plt.title('Residual Plot for Feedforward NN Model')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Time Series Plot: True vs Predicted
plt.figure(figsize=(12,5))
plt.plot(y_test, label='True')
plt.plot(final_pred_nn, label='Predicted')
plt.legend()
plt.title('Feedforward NN Predictions vs True AC_POWER (kW)')
plt.xlabel('Time Step')
plt.ylabel('AC_POWER (kW)')
plt.show()

# %% [markdown]
# ### Statistical Analysis for Feed Forward Neural Network

# %%
# 1. Load fold metrics CSV

metrics_csv = "fold_metrics_nn.csv"  # Change if needed
metrics_df_nn = pd.read_csv(metrics_csv)
metrics_df_nn
# Out:
#      fold        r2          mae         rmse  trial_number
# 0       1  0.985181   540.107599   963.463872             0
# 1       2  0.987346   657.687662   930.141827             0
# 2       3  0.985982   877.305507  1018.111413             0
# 3       4  0.993711   560.697842   713.520031             0
# 4       5  0.994176   520.145610   684.656066             0
# ..    ...       ...          ...          ...           ...
# 245     1  0.960748  1013.530429  1568.040537            49
# 246     2  0.957741  1120.544683  1699.774132            49
# 247     3  0.958174  1113.605487  1758.651801            49
# 248     4  0.961296  1179.272614  1770.035891            49
# 249     5  0.965709  1100.183341  1661.351765            49
#
# [250 rows x 5 columns]

# %%
# Describe 
desc_stats_nn = metrics_df_nn[['r2','mae','rmse']].describe()
desc_stats_nn
# Out:
#                r2          mae         rmse
# count  250.000000   250.000000   250.000000
# mean     0.988824   497.848797   819.875691
# std      0.012004   256.925249   359.163648
# min      0.926200   270.953836   483.340445
# 25%      0.987350   336.139199   569.275014
# 50%      0.993051   399.049260   700.882798
# 75%      0.995806   539.733392   912.568792
# max      0.997098  1444.624200  2268.312946

# %%
fold_stats_nn = metrics_df_nn.groupby('fold')[['r2','mae','rmse']].agg(['mean','std','min','max'])
fold_stats_nn
# Out:
#             r2                                       mae              \
#           mean       std       min       max        mean         std
# fold
# 1     0.983693  0.010481  0.926200  0.989322  528.524915  210.376509
# 2     0.988467  0.011092  0.939941  0.993675  493.850289  231.118547
# 3     0.989719  0.013439  0.933309  0.996195  494.235044  285.389415
# 4     0.991926  0.011111  0.946632  0.996801  464.602292  268.978396
# 5     0.990315  0.012464  0.936076  0.997098  508.031445  285.915063
#
#                                      rmse
#              min          max        mean         std         min          max
# fold
# 1     359.215226  1437.325349  982.841304  237.999457  817.852107  2150.083604
# 2     307.007612  1327.217083  836.949168  299.655331  657.625853  2026.373965
# 3     279.680107  1398.606336  776.550779  400.538135  530.457403  2220.693252
# 4     270.971004  1444.624200  720.682393  370.054163  508.858110  2078.480959
# 5     270.953836  1413.827175  782.354813  413.431890  483.340445  2268.312946

# %%
# Visualize
sns.set(style="whitegrid")

# Boxplots
plt.figure(figsize=(12,5))
plt.subplot(1,3,1)
sns.boxplot(x='fold', y='r2', data=metrics_df_nn)
plt.title('R² per Fold')

plt.subplot(1,3,2)
sns.boxplot(x='fold', y='mae', data=metrics_df_nn)
plt.title('MAE per Fold')

plt.subplot(1,3,3)
sns.boxplot(x='fold', y='rmse', data=metrics_df_nn)
plt.title('RMSE per Fold')

plt.tight_layout()
plt.show()

# %%
# Line plots: metric trend across trials
plt.figure(figsize=(12,4))
sns.lineplot(x='trial_number', y='r2', hue='fold', data=metrics_df_nn, marker='o')
plt.title("R² across Trials per Fold")
plt.xlabel("Trial Number")
plt.ylabel("R²")
plt.show()

# %%
# Example: ANOVA to check if R² differs significantly between folds
fold_r2_groups = [metrics_df_nn[metrics_df_nn['fold']==f]['r2'] for f in metrics_df_nn['fold'].unique()]
anova_result = f_oneway(*fold_r2_groups)
print("\nANOVA for R² across folds")
print(f"F-statistic: {anova_result.statistic:.4f}, p-value: {anova_result.pvalue:.4f}")

# Paired t-test example: fold 1 vs fold 2 R²
t_stat, p_val = ttest_rel(metrics_df_nn[metrics_df_nn['fold']==1]['r2'].values,
                          metrics_df_nn[metrics_df_nn['fold']==2]['r2'].values)
print("\nPaired t-test Fold 1 vs Fold 2 R²:")
print(f"t-statistic: {t_stat:.4f}, p-value: {p_val:.4f}")
# Out:
# ANOVA for R² across folds
# F-statistic: 3.5298, p-value: 0.0080
#
# Paired t-test Fold 1 vs Fold 2 R²:
# t-statistic: -7.8712, p-value: 0.0000

# %%
# 7. Confidence intervals
def compute_ci(data, confidence=0.95):
    mean = np.mean(data)
    sem  = stats.sem(data)
    ci_lower, ci_upper = stats.t.interval(confidence, len(data)-1, loc=mean, scale=sem)
    return mean, ci_lower, ci_upper

print("\n95% Confidence Intervals ")
for metric in ['r2','mae','rmse']:
    mean, ci_lower, ci_upper = compute_ci(metrics_df_nn[metric])
    print(f"{metric}: Mean={mean:.4f}, 95% CI=({ci_lower:.4f}, {ci_upper:.4f})")
# Out:
# 95% Confidence Intervals
# r2: Mean=0.9888, 95% CI=(0.9873, 0.9903)
# mae: Mean=497.8488, 95% CI=(465.8450, 529.8525)
# rmse: Mean=819.8757, 95% CI=(775.1367, 864.6147)

# %%
best_row = metrics_df.loc[metrics_df['r2'].idxmax()]
print("\n Best Trial/Fold")
print(best_row)
print(f"Trial {best_row['trial_number']} - Fold {best_row['fold']} has the highest R²: {best_row['r2']:.4f}")
# Out:
#  Best Trial/Fold
# fold              5.000000
# r2                0.997098
# mae             290.114653
# rmse            483.340445
# trial_number     11.000000
# Name: 59, dtype: float64
# Trial 11.0 - Fold 5.0 has the highest R²: 0.9971

# %% [markdown]
# # Model Comparison and Statistical Analysis

# %% [markdown]
# ## Running models for different k fold

# %% [markdown]
# As now we have got the best hyper parameters using that hyper parameter for different k fold we will extract different results which are r square , rmse and mae. We will keep those results in a csv and run statistical analysis

# %% [markdown]
# ## Generating Results for Random Forest

# %% [markdown]
# We will extract the hyper parameters from optuna beysian study at first

# %%
# Extracting the best hyper parameters for random forest
best_params_rf = study_rf.best_trial.params
print(best_params)
# Out:
# {'n_estimators': 743, 'max_depth': 27, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 0.7396079117662695, 'bootstrap': True}

# %%
best_params_rf = study_rf.best_trial.params

# RandomForest requires these additional parameters:
best_params_rf["random_state"] = None       # allow randomness for repeated runs
best_params_rf["n_jobs"] = -1               # use all CPU cores

print("Loaded Hyperparameters:", best_params_rf)

# Output CSV file

output_csv = "rf_repeated_final_metrics.csv"

# Initialize CSV with headers
pd.DataFrame(columns=["fold", "r2", "mae", "rmse", "trial_number"]).to_csv(
    output_csv, index=False
)

# Run Repeated Group K-Fold
NUM_REPEATS = 50

global_trial_num = 0

for repeat in range(NUM_REPEATS):
    print(f"Running repetition {repeat + 1} of {NUM_REPEATS}...")

    best_params_rf["random_state"] = repeat
    best_params_rf["n_jobs"] = -1  # Use all CPUs

    fold_metrics = []
    
    # Perform group k-fold split (5 folds)
    for fold_data in group_kfold_split_by_date(
        df,
        date_col="DATE",
        feature_cols=features,
        target_col="AC_POWER",
        n_splits=5
    ):
        X_train = fold_data["X_train"]
        X_test  = fold_data["X_test"]
        y_train = fold_data["y_train"].ravel()
        y_test  = fold_data["y_test"].ravel()
        y_scaler = fold_data["y_scaler"]


        # Train Random Forest
        model = RandomForestRegressor(**best_params_rf)
        model.fit(X_train, y_train)

        # Predict
        preds = model.predict(X_test).reshape(-1, 1)
        preds = y_scaler.inverse_transform(preds)
        real_y = y_scaler.inverse_transform(y_test.reshape(-1,1))

        # Metrics
        r2     = r2_score(real_y, preds)
        mae    = mean_absolute_error(real_y, preds)
        rmse   = np.sqrt(mean_squared_error(real_y, preds))

        # Append row to CSV

        row = pd.DataFrame([{
            "fold": fold_data["fold"] + 1,  # show fold as 1–5
            "r2": r2,
            "mae": mae,
            "rmse": rmse,
            "trial_number": repeat
        }])

        row.to_csv(output_csv, mode="a", header=False, index=False)

        global_trial_num += 1

print("\nFinished 50 repeated runs!")
print("Saved to:", output_csv)
# Out:
# Loaded Hyperparameters: {'n_estimators': 743, 'max_depth': 27, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 0.7396079117662695, 'bootstrap': True, 'random_state': None, 'n_jobs': -1}
# Running repetition 1 of 50...
# Running repetition 2 of 50...
# Running repetition 3 of 50...
# Running repetition 4 of 50...
# Running repetition 5 of 50...
# Running repetition 6 of 50...
# Running repetition 7 of 50...
# Running repetition 8 of 50...
# Running repetition 9 of 50...
# Running repetition 10 of 50...
# Running repetition 11 of 50...
# Running repetition 12 of 50...
# Running repetition 13 of 50...
# Running repetition 14 of 50...
# Running repetition 15 of 50...
# Running repetition 16 of 50...
# Running repetition 17 of 50...
# Running repetition 18 of 50...
# Running repetition 19 of 50...
# Running repetition 20 of 50...
# Running repetition 21 of 50...
# Running repetition 22 of 50...
# Running repetition 23 of 50...
# Running repetition 24 of 50...
# Running repetition 25 of 50...
# Running repetition 26 of 50...
# Running repetition 27 of 50...
# Running repetition 28 of 50...
# Running repetition 29 of 50...
# Running repetition 30 of 50...
# Running repetition 31 of 50...
# Running repetition 32 of 50...
# Running repetition 33 of 50...
# Running repetition 34 of 50...
# Running repetition 35 of 50...
# Running repetition 36 of 50...
# Running repetition 37 of 50...
# Running repetition 38 of 50...
# Running repetition 39 of 50...
# Running repetition 40 of 50...
# Running repetition 41 of 50...
# Running repetition 42 of 50...
# Running repetition 43 of 50...
# Running repetition 44 of 50...
# Running repetition 45 of 50...
# Running repetition 46 of 50...
# Running repetition 47 of 50...
# Running repetition 48 of 50...
# Running repetition 49 of 50...
# Running repetition 50 of 50...
#
# Finished 50 repeated runs!
# Saved to: rf_repeated_final_metrics.csv

# %% [markdown]
# ## Generating Results for XGBoost Regressor

# %%
# Extracting the best hyper parameters for xgboost
best_params_xgb = study_xgb.best_trial.params
print(best_params_xgb)
# Out:
# {'n_estimators': 991, 'max_depth': 3, 'learning_rate': 0.014646716221084499, 'subsample': 0.5259883755764126, 'colsample_bytree': 0.8337136984745002, 'gamma': 0.0007502984096079968, 'reg_alpha': 0.9595383922801118, 'reg_lambda': 0.06689595344445792}

# %%
best_params_rf = study_xgb.best_trial.params

# RandomForest requires these additional parameters:
best_params_rf["random_state"] = None       # allow randomness for repeated runs
best_params_rf["n_jobs"] = -1               # use all CPU cores

print("Loaded Hyperparameters:", best_params_rf)

# Output CSV file

output_csv = "xgb_repeated_final_metrics.csv"

# Initialize CSV with headers
pd.DataFrame(columns=["fold", "r2", "mae", "rmse", "trial_number"]).to_csv(
    output_csv, index=False
)

# Run Repeated Group K-Fold
NUM_REPEATS = 50

global_trial_num = 0

for repeat in range(NUM_REPEATS):
    print(f"Running repetition {repeat + 1} of {NUM_REPEATS}...")

    best_params_rf["random_state"] = repeat
    best_params_rf["n_jobs"] = -1  # Use all CPUs

    fold_metrics = []
    
    # Perform group k-fold split (5 folds)
    for fold_data in group_kfold_split_by_date(
        df,
        date_col="DATE",
        feature_cols=features,
        target_col="AC_POWER",
        n_splits=5
    ):
        X_train = fold_data["X_train"]
        X_test  = fold_data["X_test"]
        y_train = fold_data["y_train"].ravel()
        y_test  = fold_data["y_test"].ravel()
        y_scaler = fold_data["y_scaler"]


        # Train Random Forest
        model = xgb.XGBRegressor(**best_params_rf)
        model.fit(X_train, y_train)

        # Predict
        preds = model.predict(X_test).reshape(-1, 1)
        preds = y_scaler.inverse_transform(preds)
        real_y = y_scaler.inverse_transform(y_test.reshape(-1,1))

        # Metrics
        r2     = r2_score(real_y, preds)
        mae    = mean_absolute_error(real_y, preds)
        rmse   = np.sqrt(mean_squared_error(real_y, preds))

        # Append row to CSV

        row = pd.DataFrame([{
            "fold": fold_data["fold"] + 1,  # show fold as 1–5
            "r2": r2,
            "mae": mae,
            "rmse": rmse,
            "trial_number": repeat
        }])

        row.to_csv(output_csv, mode="a", header=False, index=False)

        global_trial_num += 1

print("\nFinished 50 repeated runs!")
print("Saved to:", output_csv)
# Out:
# Loaded Hyperparameters: {'n_estimators': 991, 'max_depth': 3, 'learning_rate': 0.014646716221084499, 'subsample': 0.5259883755764126, 'colsample_bytree': 0.8337136984745002, 'gamma': 0.0007502984096079968, 'reg_alpha': 0.9595383922801118, 'reg_lambda': 0.06689595344445792, 'random_state': None, 'n_jobs': -1}
# Running repetition 1 of 50...
# Running repetition 2 of 50...
# Running repetition 3 of 50...
# Running repetition 4 of 50...
# Running repetition 5 of 50...
# Running repetition 6 of 50...
# Running repetition 7 of 50...
# Running repetition 8 of 50...
# Running repetition 9 of 50...
# Running repetition 10 of 50...
# Running repetition 11 of 50...
# Running repetition 12 of 50...
# Running repetition 13 of 50...
# Running repetition 14 of 50...
# Running repetition 15 of 50...
# Running repetition 16 of 50...
# Running repetition 17 of 50...
# Running repetition 18 of 50...
# Running repetition 19 of 50...
# Running repetition 20 of 50...
# Running repetition 21 of 50...
# Running repetition 22 of 50...
# Running repetition 23 of 50...
# Running repetition 24 of 50...
# Running repetition 25 of 50...
# Running repetition 26 of 50...
# Running repetition 27 of 50...
# Running repetition 28 of 50...
# Running repetition 29 of 50...
# Running repetition 30 of 50...
# Running repetition 31 of 50...
# Running repetition 32 of 50...
# Running repetition 33 of 50...
# Running repetition 34 of 50...
# Running repetition 35 of 50...
# Running repetition 36 of 50...
# Running repetition 37 of 50...
# Running repetition 38 of 50...
# Running repetition 39 of 50...
# Running repetition 40 of 50...
# Running repetition 41 of 50...
# Running repetition 42 of 50...
# Running repetition 43 of 50...
# Running repetition 44 of 50...
# Running repetition 45 of 50...
# Running repetition 46 of 50...
# Running repetition 47 of 50...
# Running repetition 48 of 50...
# Running repetition 49 of 50...
# Running repetition 50 of 50...
#
# Finished 50 repeated runs!
# Saved to: xgb_repeated_final_metrics.csv

# %% [markdown]
# ## Generating Results for Feed Forward Neural Network

# %%
# Extracting the best hyper parameters for feed forward neural network
best_params_nn = study_nn.best_trial.params
print(best_params_nn)
# Out:
# {'hidden_dim': 44, 'hidden_layers': 3, 'dropout': 0.0022924140847316475, 'activation': 'tanh', 'learning_rate': 0.0014385069197615811, 'batch_size': 64, 'epochs': 187}

# %%
# Load best hyperparameters from Optuna for FFNN
best_params_nn = study_nn.best_trial.params
print("Loaded Hyperparameters:", best_params_nn)

# Output CSV file
output_csv = "ffnn_repeated_final_metrics.csv"

# Initialize CSV with headers
pd.DataFrame(columns=["fold", "r2", "mae", "rmse", "trial_number"]).to_csv(
    output_csv, index=False
)

# Number of repeated runs
NUM_REPEATS = 50

for repeat in range(NUM_REPEATS):
    print(f"Running repetition {repeat + 1} of {NUM_REPEATS}...")

    fold_metrics = []

    # Perform group k-fold split (5 folds)
    for fold_data in group_kfold_split_by_date(
        df,
        date_col="DATE",
        feature_cols=features,
        target_col="AC_POWER",
        n_splits=5
    ):
        X_train = fold_data["X_train"]
        X_test  = fold_data["X_test"]
        y_train = fold_data["y_train"].ravel()
        y_test  = fold_data["y_test"].ravel()
        y_scaler = fold_data["y_scaler"]

        # Convert to tensors
        X_train_t = torch.tensor(X_train, dtype=torch.float32).to(device)
        y_train_t = torch.tensor(y_train, dtype=torch.float32).view(-1,1).to(device)
        X_test_t  = torch.tensor(X_test, dtype=torch.float32).to(device)

        # DataLoader
        train_ds = TensorDataset(X_train_t, y_train_t)
        train_loader = DataLoader(train_ds, batch_size=best_params_nn["batch_size"], shuffle=True)

        # Build model with best hyperparameters
        model = FeedForwardNN(
            input_dim=X_train.shape[1],
            hidden_dim=best_params_nn["hidden_dim"],
            hidden_layers=best_params_nn["hidden_layers"],
            dropout=best_params_nn["dropout"],
            activation_name=best_params_nn["activation"]
        ).to(device)

        optimizer = optim.Adam(model.parameters(), lr=best_params_nn["learning_rate"])
        loss_fn = nn.MSELoss()

        # Set random seed for reproducibility per repetition
        torch.manual_seed(repeat)
        np.random.seed(repeat)

        # Training loop
        model.train()
        for epoch in range(best_params_nn["epochs"]):
            for xb, yb in train_loader:
                optimizer.zero_grad()
                preds = model(xb)
                loss = loss_fn(preds, yb)
                loss.backward()
                optimizer.step()

        # Prediction
        model.eval()
        with torch.no_grad():
            preds = model(X_test_t).cpu().numpy().reshape(-1,1)

        # Inverse scaling
        preds = y_scaler.inverse_transform(preds)
        real_y = y_scaler.inverse_transform(y_test.reshape(-1,1))

        # Metrics
        r2   = r2_score(real_y, preds)
        mae  = mean_absolute_error(real_y, preds)
        rmse = np.sqrt(mean_squared_error(real_y, preds))

        # Append row to CSV
        row = pd.DataFrame([{
            "fold": fold_data["fold"] + 1,
            "r2": r2,
            "mae": mae,
            "rmse": rmse,
            "trial_number": repeat
        }])
        row.to_csv(output_csv, mode="a", header=False, index=False)

print("\nFinished 50 repeated runs!")
print("Saved to:", output_csv)
# Out:
# Loaded Hyperparameters: {'hidden_dim': 44, 'hidden_layers': 3, 'dropout': 0.0022924140847316475, 'activation': 'tanh', 'learning_rate': 0.0014385069197615811, 'batch_size': 64, 'epochs': 187}
# Running repetition 1 of 50...
# Running repetition 2 of 50...
# Running repetition 3 of 50...
# Running repetition 4 of 50...
# Running repetition 5 of 50...
# Running repetition 6 of 50...
# Running repetition 7 of 50...
# Running repetition 8 of 50...
# Running repetition 9 of 50...
# Running repetition 10 of 50...
# Running repetition 11 of 50...
# Running repetition 12 of 50...
# Running repetition 13 of 50...
# Running repetition 14 of 50...
# Running repetition 15 of 50...
# Running repetition 16 of 50...
# Running repetition 17 of 50...
# Running repetition 18 of 50...
# Running repetition 19 of 50...
# Running repetition 20 of 50...
# Running repetition 21 of 50...
# Running repetition 22 of 50...
# Running repetition 23 of 50...
# Running repetition 24 of 50...
# Running repetition 25 of 50...
# Running repetition 26 of 50...
# Running repetition 27 of 50...
# Running repetition 28 of 50...
# Running repetition 29 of 50...
# Running repetition 30 of 50...
# Running repetition 31 of 50...
# Running repetition 32 of 50...
# Running repetition 33 of 50...
# Running repetition 34 of 50...
# Running repetition 35 of 50...
# Running repetition 36 of 50...
# Running repetition 37 of 50...
# Running repetition 38 of 50...
# Running repetition 39 of 50...
# Running repetition 40 of 50...
# Running repetition 41 of 50...
# Running repetition 42 of 50...
# Running repetition 43 of 50...
# Running repetition 44 of 50...
# Running repetition 45 of 50...
# Running repetition 46 of 50...
# Running repetition 47 of 50...
# Running repetition 48 of 50...
# Running repetition 49 of 50...
# Running repetition 50 of 50...
#
# Finished 50 repeated runs!
# Saved to: ffnn_repeated_final_metrics.csv

# %%
# Load all metrics
# Combining all metrics
rf_df  = pd.read_csv("rf_repeated_final_metrics.csv")
xgb_df = pd.read_csv("xgb_repeated_final_metrics.csv")
nn_df  = pd.read_csv("ffnn_repeated_final_metrics.csv")

# Add model name to each dataframe
rf_df["model"]  = "Random Forest"
xgb_df["model"] = "XGBoost"
nn_df["model"]  = "Feed Forward Neural Network"

# Combine all data
all_df = pd.concat([rf_df, xgb_df, nn_df], ignore_index=True)

# Display combined table
print("\nCombined Metrics")
print(all_df.head())
# Out:
# Combined Metrics
#    fold        r2         mae        rmse  trial_number          model
# 0     2  0.988741  347.641760  839.800609             0  Random Forest
# 1     3  0.992860  316.139869  698.678817             0  Random Forest
# 2     4  0.995306  292.905741  589.151350             0  Random Forest
# 3     5  0.996557  276.847956  527.899076             0  Random Forest
# 4     6  0.996397  273.616321  538.489609             0  Random Forest

# %%
# Computing average metrics per model
mean_metrics = all_df.groupby("model")[["r2", "mae", "rmse"]].agg(["mean", "std"])
print("\nMean Performance Per Model")
print(mean_metrics)
# Out:
# Mean Performance Per Model
#                                    r2                   mae             \
#                                  mean       std        mean        std
# model
# Feed Forward Neural Network  0.993694  0.003251  354.701587  49.858002
# Random Forest                0.993989  0.002918  301.324538  27.564435
# XGBoost                      0.991794  0.003437  408.465791  34.308193
#
#                                    rmse
#                                    mean         std
# model
# Feed Forward Neural Network  651.669399  130.742232
# Random Forest                638.199511  116.454252
# XGBoost                      751.895226  115.719797

# %%
rank_table = all_df.groupby("model").agg(
    r2_mean=("r2", "mean"),
    rmse_mean=("rmse", "mean"),
    mae_mean=("mae", "mean")
).sort_values(by="rmse_mean")

print("\nModel Ranking (Based on RMSE)")
print(rank_table)
# Out:
# Model Ranking (Based on RMSE)
#                               r2_mean   rmse_mean    mae_mean
# model
# Random Forest                0.993989  638.199511  301.324538
# Feed Forward Neural Network  0.993694  651.669399  354.701587
# XGBoost                      0.991794  751.895226  408.465791

# %%
# Box plot of r square comparison for different models
plt.figure(figsize=(7,5))
sns.boxplot(data=all_df, x="model", y="r2")
plt.title("R² Comparison Across Models")
plt.show()

# %%
# Box plot of rmse comparison between 3 different models
plt.figure(figsize=(7,5))
sns.boxplot(data=all_df, x="model", y="rmse")
plt.title("RMSE Comparison Across Models")
plt.show()

# %%
# Box plot of mae for different models
plt.figure(figsize=(7,5))
sns.boxplot(data=all_df, x="model", y="mae")
plt.title("MAE Comparison Across Models")
plt.show()

# %%
# Statistical significance test
rf_r2  = rf_df["r2"].values
xgb_r2 = xgb_df["r2"].values
nn_r2  = nn_df["r2"].values

stat, p = friedmanchisquare(rf_r2, xgb_r2, nn_r2)

print("\nFriedman Test for R²")
print("Statistic:", stat)
print("p-value:", p)
# Out:
# Friedman Test for R²
# Statistic: 334.6880000000001
# p-value: 2.1058344219508508e-73

# %%
# Fold wise comparison for different models
plt.figure(figsize=(12, 6))
sns.boxplot(data=all_df, x="fold", y="r2", hue="model")
plt.title("Fold-wise R² Comparison Across Models")
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(data=all_df, x="fold", y="rmse", hue="model")
plt.title("Fold-wise RMSE Comparison Across Models")
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(data=all_df, x="fold", y="mae", hue="model")
plt.title("Fold-wise MAE Comparison Across Models")
plt.show()

# %% [markdown]
# ## Analysis

# %% [markdown]
# Random Forest is the best model overall for this dataset.
#
# * It has the highest mean R² (0.993989), slightly above the Feed Forward Neural Network (0.993694) and clearly above XGBoost (0.991794), so it explains the most variance on average across folds.
#
# * It achieves the lowest mean RMSE (638.2) and lowest mean MAE (301.3), meaning its prediction errors are both smaller and more stable than the other two models.
#
# * The fold‑wise boxplots show Random Forest with very tight, consistently high R² and low error across all folds, while XGBoost shows clearly worse performance and the neural network, although strong, is more variable.
#
# * The Friedman test for R² (statistic ≈ 334.69, p ≈ 2.1×10⁻⁷³) confirms that the performance differences between the three models are statistically significant, not due to random chance.

# %% [markdown]
# # Fitting Testing

# %% [markdown]
# # References

# %% [markdown]
# Stats Stack Exchange (2017). What is the meaning of "gold data"? Available at: https://stats.stackexchange.com/questions/296828/what-is-the-meaning-of-gold-data (Accessed: 21 November 2025)
#
# ScienceDirect (n.d.) Gold Standard Data. Available at: https://www.sciencedirect.com/topics/computer-science/gold-standard-data (Accessed: 21 November 2025)
#
# Kaggle (n.d.) Solar Power Generation Data. Available at: https://www.kaggle.com/datasets/anikannal/solar-power-generation-data (Accessed: 21 November 2025)
#
# Solar Panel. Available at: https://en.wikipedia.org/wiki/Solar_panel (Accessed: 21 November 2025)
#
# United Nations Sustainable Development Goal 7: Affordable and Clean Energy. Available at: https://globalgoals.org/goals/7-affordable-and-clean-energy/ (Accessed: 21 November 2025)
#
# The environmental factors affecting solar photovoltaic output. Available at: https://www.sciencedirect.com/science/article/pii/S1364032124007998 (Accessed: 21 November 2025)
#
# The top 10 manufacturing companies are committed to reducing their carbon footprint. Available at: https://manufacturing-today.com/news/top-ten-manufacturing-companies-committed-to-reducing-their-carbon-footprint/ (Accessed: 21 November 2025)
#
# Util in a software project. Available at: https://stackoverflow.com/questions/3305511/is-it-good-to-have-utils-class-in-your-software-project (Accessed: 22 November 2025)
#
# Random Forest Regressor using Scikit Learn. Available at: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html (Accessed: 23 November 2025)
#
# XGBoost algorithm how it works. Available at: https://www.geeksforgeeks.org/machine-learning/xgboost/ (Accessed: 23 November 2025)
#
# Optimizing Machine Learning Models: Comparing Grid Search, Randomized Search, and Optuna. Available at : https://dev.to/iemsaad/optimizing-machine-learning-models-comparing-grid-search-randomized-search-and-optuna-4hnf#:~:text=Optuna's%20strength%20lies%20in%20its,complex%20models%20or%20large%20datasets. (Accessed: 24 November 2025)
#
# PRACTICAL BAYESIAN OPTIMIZATION OF MACHINE LEARNING ALGORITHMS. Available at: https://arxiv.org/abs/1206.2944 (Accessed : 24 November 2025)
#
# Feed Forward Neural Network From Scratch. Available at: https://medium.com/@andresberejnoi/how-to-build-a-feedforward-neural-network-in-python-andres-berejnoi-a96668c025e5 (Accessed: 30 November 2025)
#
# How To Compare Machine Learning Algorithms in Python with scikit-learn. Available at: https://machinelearningmastery.com/compare-machine-learning-algorithms-python-scikit-learn/ (Accessed: 30 November 2025)
#
# How to perform Friedman test in python. Available at: https://www.statology.org/friedman-test-python/ (Accessed: 30 November 2025)
